# %%
import os
from pathlib import Path

# %%
os.chdir(Path(os.getcwd()).parents[0])

# %%
import utils

# %%
import pandas as pd
import xarray as xr

# %%
a = pd.read_hdf('/global/homes/j/jbbutler/extreme_antarctic_ARs/data/ar_database/dataframe_eps12_eps500_minpts5_reppts10/landfalling_storm_quantities_df.h5')

# %%
a.trajectory.iloc[1]
# Out:
#                   time     avg_lon    avg_lat
# 0  1980-01-06 18:00:00  115.291563 -51.471830
# 1  1980-01-06 21:00:00  117.454001 -52.252114
# 2  1980-01-07 00:00:00  119.486686 -52.822672
# 3  1980-01-07 03:00:00  121.329192 -53.645634
# 4  1980-01-07 06:00:00  122.858413 -54.777622
# 5  1980-01-07 09:00:00  124.100610 -56.177225
# 6  1980-01-07 15:00:00  126.926780 -57.499878
# 7  1980-01-07 18:00:00  127.852239 -57.720525
# 8  1980-01-07 21:00:00  128.437891 -58.886564
# 9  1980-01-08 00:00:00  128.402431 -60.108920
# 10 1980-01-08 03:00:00  128.099866 -61.454139
# 11 1980-01-08 06:00:00  128.184392 -62.600344
# 12 1980-01-08 09:00:00  126.568693 -64.467312
# 13 1980-01-08 12:00:00  123.297224 -66.401252
