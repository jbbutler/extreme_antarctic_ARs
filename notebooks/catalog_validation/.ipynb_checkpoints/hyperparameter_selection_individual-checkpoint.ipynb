# %% [markdown]
# # Hyperparameter Selection
#
# Notebook to explore the optimal set of clustering hyperparameters, by looking at aggregate plots from papers, as well as tracking known storms.
#
# There are several hyperparameters we can vary:
# + $\epsilon_{space}$
# + $\epsilon_{time}$
# + min_pts
# + rep_pts
#
# We will explore different combinations of these hyperparameters, and see how good/bad these choices are at detecting important extreme events.
#
# Defaults are the following, and in the below, the parameter value listed indicates the one which was changed.
# + $\epsilon_{space} = 500$ km
# + $\epsilon_{time} = 12$ hr
# + min_pts: 5
# + rep_pts: 10

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import os

import matplotlib.path as mpath
import matplotlib.colors
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.util import add_cyclic_point

from matplotlib import animation
import matplotlib
matplotlib.use("Agg")
from IPython.display import Video
from matplotlib.cm import prism

from ipywidgets import IntProgress
from IPython.display import display

repo_dir = str(Path(os.getcwd()).parents[1])

os.chdir(repo_dir + '/scripts/')
from utils import display_catalog
import utils

ani_dir = repo_dir + '/animations/hyperparam_selection/'
data_dir = repo_dir + '/data/hyperparam_selection/'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 25
#      21 from IPython.display import display
#      23 repo_dir = str(Path(os.getcwd()).parents[1])
# ---> 25 os.chdir(repo_dir + '/scripts/')
#      26 from utils import display_catalog
#      27 import utils
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/scripts/'

# %%
def compute_duration(ar_da):
    days = (ar_da.time.max() - ar_da.time.min()).values.astype('timedelta64[h]').astype(int) + np.timedelta64(3, 'h')
    return days

def add_start_date(ar_da):
    start = ar_da.time.min().values
    return start

def add_end_date(ar_da):
    end = ar_da.time.max().values
    return end

# %%
def make_movie(stormtime_df, title):
    '''
    Function that constructs an animation of ARs in a stormtime version of the AR catalog.

    Inputs
        stormtime_df (pandas DataFrame): same as above
        title (string): the title to print on the animation

    Outputs
        ani (Matplotlib Animation): an animation object, as far as I know it must be saved first in order to view it
    '''

    # define the times of the movie, and mappings between AR labels and colors
    movie_times = pd.date_range(start=stormtime_df.time.min(), end=stormtime_df.time.max(), freq='3h')
    unique_clusters = stormtime_df['label'].unique()
    color_mapping = {unique_clusters[j]:prism(j/len(unique_clusters)) for j in range(len(unique_clusters)) }

    # plot the jth frame of the movie (need as input to matplotlib animation constructor)
    def plt_time(j):
        time_pt = movie_times[j]

        if (time_pt == stormtime_df.time).any():
            dat = stormtime_df[stormtime_df['time'] == time_pt]
            n_clusts = dat.shape[0]

            for i in range(n_clusts):
                cluster = dat['label'].iloc[i]
                ax.scatter(dat['lon'].iloc[i], dat['lat'].iloc[i], transform=ccrs.PlateCarree(), s=1, color=color_mapping[cluster], label=str(cluster), zorder=30)
        
            ax.legend()

        ax.set_extent([-180,180,-90,-39], ccrs.PlateCarree())
        ice_shelf_poly = cfeature.NaturalEarthFeature('physical', 'antarctic_ice_shelves_polys', '50m',edgecolor='none',facecolor='lightcyan') # 10m, 50m, 110m
        ax.add_feature(ice_shelf_poly,linewidth=3)
        ice_shelf_line = cfeature.NaturalEarthFeature('physical', 'antarctic_ice_shelves_lines', '50m',edgecolor='black',facecolor='none') # 10m, 50m, 110m
        ax.add_feature(ice_shelf_line,linewidth=1,zorder=13)
        ax.coastlines(resolution='110m',linewidth=1,zorder=32)

    
        # Map extent 
        theta = np.linspace(0, 2*np.pi, 100)
        center, radius = [0.5, 0.5], 0.5
        verts = np.vstack([np.sin(theta), np.cos(theta)]).T
        circle = mpath.Path(verts * radius + center)
        ax.set_boundary(circle, transform=ax.transAxes)
        ax.gridlines(alpha=0.5, zorder=33)
    
        time_ts = pd.Timestamp(time_pt)
        ax.set_title(f'{time_ts.month}/{time_ts.day}/{time_ts.year}, {time_ts.hour}:00')

    # instantiate the animation
    fig, ax = plt.subplots(figsize=(5,5), subplot_kw=dict(projection=ccrs.Stereographic(central_longitude=0., central_latitude=-90.)))
    plt_time(0)
    fig.suptitle(title, fontsize=16)

    def update_img(i):
        ax.clear()
        plt_time(i)

    ani = animation.FuncAnimation(fig, update_img, frames=len(movie_times))

    return ani

def save_progress(i, n):
    '''
    Function that will be used in calls to animation.save(), just to give some progress updates as it can take a while to save!
    '''
    if i%20 == 0: {print(f'Saving frame {i}/{n}')}

# %% [markdown]
# ## Default Specifications

# %%
#catalog = pd.read_hdf('/scratch/users/butlerj/extreme_antarctic_ars/sensitivity_analysis/all_years/seed_12345eps_time_12eps_space_0.5rep_pts_10min_pts_5/storm_df.h5')
#catalog['duration'] = catalog['data_array'].apply(compute_duration)
#catalog['start_date'] = catalog['data_array'].apply(add_start_date)
#catalog['end_date'] = catalog['data_array'].apply(add_end_date)
hyperparam_dir = 'space500_time12_minpts5_reppts10/'

# %% [markdown]
# ### Individual Storms

# %% [markdown]
# #### Storm 1: March 23-24, 2015 (Bozkurt et al.)

# %%
#start_date = pd.to_datetime('3/18/2015')
#end_date = pd.to_datetime('3/28/2015')
#catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
#catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/03_2324_15.h5', key='df')
catalog_subset = pd.read_hdf(data_dir + hyperparam_dir + '03_2324_15.h5')
stormtime_df = utils.to_stormtime_format(catalog_subset)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 6
#       1 #start_date = pd.to_datetime('3/18/2015')
#       2 #end_date = pd.to_datetime('3/28/2015')
#       3 #catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
#       4 #catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/03_2324_15.h5', key='df')
#       5 catalog_subset = pd.read_hdf(data_dir + hyperparam_dir + '03_2324_15.h5')
# ----> 6 stormtime_df = utils.to_stormtime_format(catalog_subset)
#
# AttributeError: module 'utils' has no attribute 'to_stormtime_format'

# %% [markdown]
# #### Storm 2: January 8-10, 2019 (Gehring 2022)

# %%
start_date = pd.to_datetime('1/6/2019')
end_date = pd.to_datetime('1/12/2019')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/01_0810_19.h5', key='df')

stormtime_df = utils.to_stormtime_format(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/1868449750.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/01_0810_19.h5', key='df')

# %% [markdown]
# #### Storm 3: February 7-9, 2022 (Gorodetskaya 2023)

# %%
start_date = pd.to_datetime('2/4/2022')
end_date = pd.to_datetime('2/9/2022')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/02_0409_22.h5', key='df')


stormtime_df = utils.to_stormtime_format(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/867365323.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/02_0409_22.h5', key='df')

# %% [markdown]
# #### Storm 4: November 16-17, 2018 (Gorodetskaya 2020)

# %%
start_date = pd.to_datetime('11/14/2018')
end_date = pd.to_datetime('11/20/2018')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/11_1617_18.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/1539517715.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/11_1617_18.h5', key='df')

# %% [markdown]
# #### Storm 5: December 18, 2018 (Gorodetskaya 2020)

# %%
start_date = pd.to_datetime('12/15/2018')
end_date = pd.to_datetime('12/20/2018')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/12_1818_18.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/1674918959.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/12_1818_18.h5', key='df')

# %% [markdown]
# #### Storm 6-8 (family event): (1) February 2, 2020; (2) February 3-5, 2020; (3) February 7-8, 2020 (Maclennan 2023)

# %%
start_date = pd.to_datetime('1/27/2020')
end_date = pd.to_datetime('2/9/2020')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/02_family_20.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/254987630.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/02_family_20.h5', key='df')

# %% [markdown]
# #### Storm 9: March 14-18, 2022 (Wille 2024)

# %%
start_date = pd.to_datetime('3/12/2022')
end_date = pd.to_datetime('3/20/2022')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/03_1418_22.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/2046176530.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/03_1418_22.h5', key='df')

# %% [markdown]
# #### Storm 10: January 24-26, 2008 (Wille 2022)

# %%
start_date = pd.to_datetime('1/21/2008')
end_date = pd.to_datetime('1/27/2008')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/01_2426_08.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/1337665531.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts_10/01_2426_08.h5', key='df')

# %% [markdown]
# ### Aggregate Statistics/Plots

# %% [markdown]
# ## Rep Pts Variations

# %% [markdown]
# ### rep_pts = $20$

# %% [markdown]
# #### Individual Storms

# %%
catalog = pd.read_hdf('/scratch/users/butlerj/extreme_antarctic_ars/sensitivity_analysis/all_years/seed_12345eps_time_12eps_space_0.5rep_pts_20min_pts_5/storm_df.h5')
catalog['duration'] = catalog['data_array'].apply(compute_duration)
catalog['start_date'] = catalog['data_array'].apply(add_start_date)
catalog['end_date'] = catalog['data_array'].apply(add_end_date)

# %% [markdown]
# #### Storm 1: March 23-24, 2015 (Bozkurt et al.)

# %%
start_date = pd.to_datetime('3/18/2015')
end_date = pd.to_datetime('3/28/2015')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/03_2324_15.h5', key='df')
stormtime_df = utils.to_stormtime_format(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/2951301911.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/03_2324_15.h5', key='df')

# %% [markdown]
# #### Storm 2: January 8-10, 2019 (Gehring 2022)

# %%
start_date = pd.to_datetime('1/6/2019')
end_date = pd.to_datetime('1/12/2019')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/01_0810_19.h5', key='df')

stormtime_df = utils.to_stormtime_format(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/859202319.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/01_0810_19.h5', key='df')

# %% [markdown]
# #### Storm 3: February 7-9, 2022 (Gorodetskaya 2023)

# %%
start_date = pd.to_datetime('2/4/2022')
end_date = pd.to_datetime('2/9/2022')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/02_0409_22.h5', key='df')


stormtime_df = utils.to_stormtime_format(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/2170713117.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/02_0409_22.h5', key='df')

# %% [markdown]
# #### Storm 4: November 16-17, 2018 (Gorodetskaya 2020)

# %%
start_date = pd.to_datetime('11/14/2018')
end_date = pd.to_datetime('11/20/2018')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/11_1617_18.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/2628486235.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/11_1617_18.h5', key='df')

# %% [markdown]
# #### Storm 5: December 18, 2018 (Gorodetskaya 2020)

# %%
start_date = pd.to_datetime('12/15/2018')
end_date = pd.to_datetime('12/20/2018')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/12_1818_18.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/3423007324.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/12_1818_18.h5', key='df')

# %% [markdown]
# #### Storm 6-8 (family event): (1) February 2, 2020; (2) February 3-5, 2020; (3) February 7-8, 2020 (Maclennan 2023)

# %%
start_date = pd.to_datetime('1/27/2020')
end_date = pd.to_datetime('2/9/2020')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/02_family_20.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/273613232.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/02_family_20.h5', key='df')

# %% [markdown]
# #### Storm 9: March 14-18, 2022 (Wille 2024)

# %%
start_date = pd.to_datetime('3/12/2022')
end_date = pd.to_datetime('3/20/2022')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/03_1418_22.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/3013557521.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/03_1418_22.h5', key='df')

# %% [markdown]
# #### Storm 10: January 24-26, 2008 (Wille 2022)

# %%
start_date = pd.to_datetime('1/21/2008')
end_date = pd.to_datetime('1/27/2008')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/01_2426_08.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/2036129519.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time12_minpts5_reppts20/01_2426_08.h5', key='df')

# %% [markdown]
# #### Aggregate Statistics/Plots

# %% [markdown]
# ## Time Epsilon Variations

# %% [markdown]
# ### $\epsilon_{time}=16$

# %% [markdown]
# #### Individual Storms

# %%
catalog = pd.read_hdf('/scratch/users/butlerj/extreme_antarctic_ars/sensitivity_analysis/all_years/seed_12345eps_time_16eps_space_0.5rep_pts_10min_pts_5/storm_df.h5')
catalog['duration'] = catalog['data_array'].apply(compute_duration)
catalog['start_date'] = catalog['data_array'].apply(add_start_date)
catalog['end_date'] = catalog['data_array'].apply(add_end_date)

# %% [markdown]
# #### Storm 1: March 23-24, 2015 (Bozkurt et al.)

# %%
start_date = pd.to_datetime('3/18/2015')
end_date = pd.to_datetime('3/28/2015')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/03_2324_15.h5', key='df')
stormtime_df = utils.to_stormtime_format(catalog_subset)
#display_catalog(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/3546984888.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/03_2324_15.h5', key='df')

# %% [markdown]
# #### Storm 2: January 8-10, 2019 (Gehring 2022)

# %%
start_date = pd.to_datetime('1/6/2019')
end_date = pd.to_datetime('1/12/2019')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/01_0810_19.h5', key='df')

stormtime_df = utils.to_stormtime_format(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/4036494247.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/01_0810_19.h5', key='df')

# %% [markdown]
# #### Storm 3: February 7-9, 2022 (Gorodetskaya 2023)

# %%
start_date = pd.to_datetime('2/2/2022')
end_date = pd.to_datetime('2/12/2022')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/02_0409_22.h5', key='df')

#stormtime_df = utils.to_stormtime_format(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/1706889901.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/02_0409_22.h5', key='df')

# %% [markdown]
# #### Storm 4: November 16-17, 2018 (Gorodetskaya 2020)

# %%
start_date = pd.to_datetime('11/14/2018')
end_date = pd.to_datetime('11/20/2018')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/11_1617_18.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/2786154302.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/11_1617_18.h5', key='df')

# %% [markdown]
# #### Storm 5: December 18, 2018 (Gorodetskaya 2020)

# %%
start_date = pd.to_datetime('12/15/2018')
end_date = pd.to_datetime('12/20/2018')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/12_1818_18.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/529613021.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/12_1818_18.h5', key='df')

# %% [markdown]
# #### Storm 6-8 (family event): (1) February 2, 2020; (2) February 3-5, 2020; (3) February 7-8, 2020 (Maclennan 2023)

# %%
start_date = pd.to_datetime('1/27/2020')
end_date = pd.to_datetime('2/9/2020')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/02_family_20.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/3660474980.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/02_family_20.h5', key='df')

# %% [markdown]
# #### Storm 9: March 14-18, 2022 (Wille 2024)

# %%
start_date = pd.to_datetime('3/12/2022')
end_date = pd.to_datetime('3/20/2022')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/03_1418_22.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/4190787582.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/03_1418_22.h5', key='df')

# %% [markdown]
# #### Storm 10: January 24-26, 2008 (Wille 2022)

# %%
start_date = pd.to_datetime('1/21/2008')
end_date = pd.to_datetime('1/27/2008')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/01_2426_08.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/1114206458.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time16_minpts5_reppts10/01_2426_08.h5', key='df')

# %% [markdown]
# ### $\epsilon_{time}=18$

# %% [markdown]
# #### Individual Storms

# %%
catalog = pd.read_hdf('/scratch/users/butlerj/extreme_antarctic_ars/sensitivity_analysis/all_years/seed_12345eps_time_18eps_space_0.5rep_pts_10min_pts_5/storm_df.h5')
catalog['duration'] = catalog['data_array'].apply(compute_duration)
catalog['start_date'] = catalog['data_array'].apply(add_start_date)
catalog['end_date'] = catalog['data_array'].apply(add_end_date)

# %% [markdown]
# #### Storm 1: March 23-24, 2015 (Bozkurt et al.)

# %%
start_date = pd.to_datetime('3/18/2015')
end_date = pd.to_datetime('3/28/2015')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/03_2324_15.h5', key='df')
stormtime_df = utils.to_stormtime_format(catalog_subset)
#display_catalog(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/3029988409.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/03_2324_15.h5', key='df')

# %% [markdown]
# #### Storm 2: January 8-10, 2019 (Gehring 2022)

# %%
start_date = pd.to_datetime('1/6/2019')
end_date = pd.to_datetime('1/12/2019')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/01_0810_19.h5', key='df')

stormtime_df = utils.to_stormtime_format(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/811237929.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/01_0810_19.h5', key='df')

# %% [markdown]
# #### Storm 3: February 7-9, 2022 (Gorodetskaya 2023)

# %%
start_date = pd.to_datetime('2/2/2022')
end_date = pd.to_datetime('2/12/2022')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/02_0409_22.h5', key='df')

#stormtime_df = utils.to_stormtime_format(catalog_subset)
# Out:
# /tmp/ipykernel_2258123/1745278554.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/02_0409_22.h5', key='df')

# %% [markdown]
# #### Storm 4: November 16-17, 2018 (Gorodetskaya 2020)

# %%
start_date = pd.to_datetime('11/14/2018')
end_date = pd.to_datetime('11/20/2018')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/11_1617_18.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/2360261563.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/11_1617_18.h5', key='df')

# %% [markdown]
# #### Storm 5: December 18, 2018 (Gorodetskaya 2020)

# %%
start_date = pd.to_datetime('12/15/2018')
end_date = pd.to_datetime('12/20/2018')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/12_1818_18.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/614148616.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/12_1818_18.h5', key='df')

# %% [markdown]
# #### Storm 6-8 (family event): (1) February 2, 2020; (2) February 3-5, 2020; (3) February 7-8, 2020 (Maclennan 2023)

# %%
start_date = pd.to_datetime('1/27/2020')
end_date = pd.to_datetime('2/9/2020')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/02_family_20.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/3007054348.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/02_family_20.h5', key='df')

# %% [markdown]
# #### Storm 9: March 14-18, 2022 (Wille 2024)

# %%
start_date = pd.to_datetime('3/12/2022')
end_date = pd.to_datetime('3/20/2022')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/03_1418_22.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/2072666401.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/03_1418_22.h5', key='df')

# %% [markdown]
# #### Storm 10: January 24-26, 2008 (Wille 2022)

# %%
start_date = pd.to_datetime('1/21/2008')
end_date = pd.to_datetime('1/27/2008')
catalog_subset = catalog[(catalog.start_date >= start_date) & (catalog.start_date <= end_date)]
catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/01_2426_08.h5', key='df')
# Out:
# /tmp/ipykernel_2258123/2495769481.py:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['data_array'], dtype='object')]
#
#   catalog_subset.to_hdf('/accounts/grad/butlerj/extreme_antarctic_ARs/data/hyperparam_selection/space500_time18_minpts5_reppts10/01_2426_08.h5', key='df')
