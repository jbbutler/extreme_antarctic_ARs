# %%
library(tidyr)
library(dplyr)
source('/global/u1/j/jbbutler/extreme_antarctic_ARs/git_packages/erf/R/fit_erf.R')
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
catalog_path <- '/global/homes/j/jbbutler/extreme_antarctic_ARs/data/ar_database/dataframe_eps12_eps500_minpts5_reppts10/landfalling_df_no_da.csv'
dat <- read.csv(catalog_path)

# %%
filtered_dat <- dat %>% filter(max_landfalling_v850hPa > 0, max_ocean_SLP_gradient >= 0)
filtered_dat <- filtered_dat %>% mutate(cumulative_rainfall_ais = cumulative_rainfall_ais/(10^13), cumulative_snowfall_ais = cumulative_snowfall_ais/(10^13))

# %%
X <- filtered_dat %>% select(c('cumulative_landfalling_area', 'max_IWV_ais', 'max_ocean_SLP_gradient', 'max_landfalling_v850hPa'))
Ys <- filtered_dat %>% select(c('cumulative_snowfall_ais', 'max_T2m_ais'))
