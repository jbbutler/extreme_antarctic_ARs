# %% [markdown]
# # MERRA-2 Streaming Test

# %% [markdown]
# Notebook showing how we can stream NASA's MERRA-2 data directly from the relevant S3 AWS bucket, instead of having to download it all.
#
# Jimmy Butler, 2024, following along with [this notebook](https://disc.gsfc.nasa.gov/information/howto?keywords=%22Earthdata%20Cloud%22&title=How%20to%20Directly%20Access%20MERRA-2%20Data%20from%20an%20S3%20Bucket%20with%20Python%20from%20a%20Cloud%20Environment).

# %%
from netrc import netrc
import xarray as xr
import boto3
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.util import add_cyclic_point
from IPython.display import display, Markdown
import warnings
import os
import requests
import s3fs

import matplotlib.pyplot as plt
import matplotlib
import numpy as np

from matplotlib import animation
from IPython.display import Video

# %% [markdown]
# For some reason, you can only stream the data if you are in AWS us-west-2 region. This little code block checks that you are in the right region.

# %%
if (boto3.client('s3').meta.region_name == 'us-west-2'):
    display(Markdown('### us-west-2 Region Check: &#x2705;'))
else:
    display(Markdown('### us-west-2 Region Check: &#10060;'))
    raise ValueError('Your notebook is not running inside the AWS us-west-2 region, and will not be able to directly access NASA Earthdata S3 buckets')
# Out:
# ### us-west-2 Region Check: &#x2705;

# %% [markdown]
# Login credentials stuff.

# %%
urs = 'urs.earthdata.nasa.gov'    # Earthdata URL endpoint for authentication
prompts = ['Enter NASA Earthdata Login Username: ',
           'Enter NASA Earthdata Login Password: ']

netrc_name = ".netrc"

# Determine if netrc file exists, and if so, if it includes NASA Earthdata Login Credentials
try:
    netrcDir = os.path.expanduser(f"~/{netrc_name}")
    # Check credentials against URS, and if username exists
    netrc(netrcDir).authenticators(urs)[0]

# Below, create a netrc file and prompt user for NASA Earthdata Login Username and Password
except FileNotFoundError:
    homeDir = os.path.expanduser("~")
    Popen('touch {0}{2} | echo machine {1} >> {0}{2}'.format(homeDir + os.sep, urs, netrc_name), shell=True)
    Popen('echo login {} >> {}{}'.format(getpass(prompt=prompts[0]), homeDir + os.sep, netrc_name), shell=True)
    Popen('echo \'password {} \'>> {}{}'.format(getpass(prompt=prompts[1]), homeDir + os.sep, netrc_name), shell=True)
    # Set restrictive permissions
    Popen('chmod 0600 {0}{1}'.format(homeDir + os.sep, netrc_name), shell=True)

# %% [markdown]
# Then, you get an S3 token to access the data bucket, but apparently this only lasts for a couple hours and may need to be rerun periodically.

# %%
gesdisc_s3 = "https://data.gesdisc.earthdata.nasa.gov/s3credentials"

# Define a function for S3 access credentials

def begin_s3_direct_access(url: str=gesdisc_s3):
    response = requests.get(url).json()
    return s3fs.S3FileSystem(key=response['accessKeyId'],
                             secret=response['secretAccessKey'],
                             token=response['sessionToken'],
                             client_kwargs={'region_name':'us-west-2'})

fs = begin_s3_direct_access()

# Check that the file system is intact as an S3FileSystem object, which means that token is valid
# Common causes of rejected S3 access tokens include incorrect passwords stored in the netrc file, or a non-existent netrc file
type(fs)
# Out:
# s3fs.core.S3FileSystem

# %%
# Files are organized by s3://gesdisc-cumulus-prod-protected/MERRA2/M2T1NXSLV.5.12.4/year/mo/*.nc4

days = [15, 16, 17, 18]
datasets = []

for day in days:
    
    path = 's3://gesdisc-cumulus-prod-protected/MERRA2/M2I1NXASM.5.12.4/2022/03/MERRA2_400.inst1_2d_asm_Nx.202203'+ str(day) +'.nc4'
    dat = xr.open_dataset(fs.open(path), decode_cf=True,)
    antarctic_dat = dat.sel(lat = slice(-90.0, -50.0), lon = slice(-180, 179.4))
    datasets.append(antarctic_dat[['T10M', 'TQV', 'V10M']])

# %%
tot_dataset = xr.concat(datasets, dim='time')

# %% [markdown]
# ### Plotting Moisture During the Antarctic Heat Wave AR

# %%
fig, ax = plt.subplots(figsize=(5,5), subplot_kw=dict(projection=ccrs.Stereographic(central_longitude=0., central_latitude=-90.)))
ax.set_extent([-180,179.4,-90,-50], ccrs.PlateCarree())
ax.coastlines(resolution='110m',linewidth=0.2,zorder=14)

minimum = tot_dataset.TQV.min().to_numpy()
maximum = tot_dataset.TQV.max().to_numpy()

CS = ax.contourf(tot_dataset.lon,tot_dataset.lat, tot_dataset.TQV[0,:,:],transform=ccrs.PlateCarree(), levels=10, vmin=minimum, vmax=maximum)
plt.title(str(tot_dataset.time.dt.date.to_numpy()[0]) + ', ' + str(tot_dataset.time.dt.time.to_numpy()[0]))

fig.colorbar(CS)
fig.suptitle('IWV (kg/m$^2$)', fontsize=16)

def update_img(i):
    ax.clear()
    ax.set_extent([-180,180,-90,-50], ccrs.PlateCarree())
    ax.coastlines(resolution='110m',linewidth=0.2,zorder=14)
    ax.contourf(tot_dataset.lon,tot_dataset.lat, tot_dataset.TQV[i,:,:],transform=ccrs.PlateCarree(), vmin=minimum, vmax=maximum, levels=10)
    ax.set_title(str(tot_dataset.time.dt.date.to_numpy()[i]) + ', ' + str(tot_dataset.time.dt.time.to_numpy()[i]))

ani = animation.FuncAnimation(fig, update_img, frames=len(tot_dataset.time))

# %%
ani.save('iwv_2022heatwave.mp4')

# %%
Video('iwv_2022heatwave.mp4')
# Out:
# <video src="iwv_2022heatwave.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### 10M Temperature

# %%
fig, ax = plt.subplots(figsize=(5,5), subplot_kw=dict(projection=ccrs.Stereographic(central_longitude=0., central_latitude=-90.)))
ax.set_extent([-180,179.4,-90,-50], ccrs.PlateCarree())
ax.coastlines(resolution='110m',linewidth=0.2,zorder=14)

minimum = tot_dataset.T10M.min().to_numpy() - 273.15
maximum = tot_dataset.T10M.max().to_numpy() - 273.15

CS = ax.contourf(tot_dataset.lon,tot_dataset.lat, tot_dataset.T10M[0,:,:]-273.15,transform=ccrs.PlateCarree(), levels=15, vmin=minimum, vmax=maximum)
plt.title(str(tot_dataset.time.dt.date.to_numpy()[0]) + ', ' + str(tot_dataset.time.dt.time.to_numpy()[0]))


fig.colorbar(CS)
fig.suptitle('10M Temp. (C)', fontsize=16)

def update_img(i):
    ax.clear()
    ax.set_extent([-180,180,-90,-50], ccrs.PlateCarree())
    ax.coastlines(resolution='110m',linewidth=0.2,zorder=14)
    ax.contourf(tot_dataset.lon,tot_dataset.lat, tot_dataset.T10M[i,:,:]-273.15,transform=ccrs.PlateCarree(), vmin=minimum, vmax=maximum, levels=15)
    ax.set_title(str(tot_dataset.time.dt.date.to_numpy()[i]) + ', ' + str(tot_dataset.time.dt.time.to_numpy()[i]))

ani = animation.FuncAnimation(fig, update_img, frames=len(tot_dataset.time))

# %%
ani.save('t10m_2022heatwave.mp4')

# %%
Video('t10m_2022heatwave.mp4')
# Out:
# <video src="t10m_2022heatwave.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### Meridional winds?

# %%
fig, ax = plt.subplots(figsize=(5,5), subplot_kw=dict(projection=ccrs.Stereographic(central_longitude=0., central_latitude=-90.)))
ax.set_extent([-180,179.4,-90,-50], ccrs.PlateCarree())
ax.coastlines(resolution='110m',linewidth=0.2,zorder=14)

s_wind = tot_dataset.V10M*(-1)

minimum = s_wind.min().to_numpy()
maximum = s_wind.max().to_numpy()



CS = ax.contourf(tot_dataset.lon,tot_dataset.lat, s_wind[0,:,:],transform=ccrs.PlateCarree(), levels=15, vmin=minimum, vmax=maximum)
plt.title(str(tot_dataset.time.dt.date.to_numpy()[0]) + ', ' + str(tot_dataset.time.dt.time.to_numpy()[0]))


fig.colorbar(CS)
fig.suptitle('Southern Wind Component (m/s)', fontsize=16)

def update_img(i):
    ax.clear()
    ax.set_extent([-180,180,-90,-50], ccrs.PlateCarree())
    ax.coastlines(resolution='110m',linewidth=0.2,zorder=14)
    ax.contourf(tot_dataset.lon,tot_dataset.lat, s_wind[i,:,:],transform=ccrs.PlateCarree(), vmin=minimum, vmax=maximum, levels=15)
    ax.set_title(str(tot_dataset.time.dt.date.to_numpy()[i]) + ', ' + str(tot_dataset.time.dt.time.to_numpy()[i]))

ani = animation.FuncAnimation(fig, update_img, frames=len(tot_dataset.time))

# %%
ani.save('v10m_2022heatwave.mp4')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/animation.py:231, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     230 try:
# --> 231     yield self
#     232 finally:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/animation.py:1095, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1093 for anim, d in zip(all_anim, data):
#    1094     # TODO: See if turning off blit is really necessary
# -> 1095     anim._draw_next_frame(d, blit=False)
#    1096     if progress_callback is not None:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/animation.py:1130, in Animation._draw_next_frame(self, framedata, blit)
#    1129 self._pre_draw(framedata, blit)
# -> 1130 self._draw_frame(framedata)
#    1131 self._post_draw(framedata, blit)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/animation.py:1759, in FuncAnimation._draw_frame(self, framedata)
#    1757 # Call the func with framedata and args. If blitting is desired,
#    1758 # func needs to return a sequence of any artists that were modified.
# -> 1759 self._drawn_artists = self._func(framedata, *self._args)
#    1761 if self._blit:
#
# Cell In[184], line 23, in update_img(i)
#      22 ax.coastlines(resolution='110m',linewidth=0.2,zorder=14)
# ---> 23 ax.contourf(tot_dataset.lon,tot_dataset.lat, s_wind[i,:,:],transform=ccrs.PlateCarree(), vmin=minimum, vmax=maximum, levels=15)
#      24 ax.set_title(str(tot_dataset.time.dt.date.to_numpy()[i]) + ', ' + str(tot_dataset.time.dt.time.to_numpy()[i]))
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:318, in _add_transform.<locals>.wrapper(self, *args, **kwargs)
#     317 kwargs['transform'] = transform
# --> 318 return func(self, *args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:362, in _add_transform_first.<locals>.wrapper(self, *args, **kwargs)
#     361     args = (x, y, z) + args[3:]
# --> 362 return func(self, *args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1665, in GeoAxes.contourf(self, *args, **kwargs)
#    1664 # We need to compute the dataLim correctly for contours.
# -> 1665 bboxes = [col.get_datalim(self.transData)
#    1666           for col in result.collections
#    1667           if col.get_paths()]
#    1668 if bboxes:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1665, in <listcomp>(.0)
#    1664 # We need to compute the dataLim correctly for contours.
# -> 1665 bboxes = [col.get_datalim(self.transData)
#    1666           for col in result.collections
#    1667           if col.get_paths()]
#    1668 if bboxes:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/collections.py:266, in Collection.get_datalim(self, transData)
#     265 if not transform.is_affine:
# --> 266     paths = [transform.transform_path_non_affine(p) for p in paths]
#     267     # Don't convert transform to transform.get_affine() here because
#     268     # we may have transform.contains_branch(transData) but not
#     269     # transforms.get_affine().contains_branch(transData).  But later,
#     270     # be careful to only apply the affine part that remains.
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/collections.py:266, in <listcomp>(.0)
#     265 if not transform.is_affine:
# --> 266     paths = [transform.transform_path_non_affine(p) for p in paths]
#     267     # Don't convert transform to transform.get_affine() here because
#     268     # we may have transform.contains_branch(transData) but not
#     269     # transforms.get_affine().contains_branch(transData).  But later,
#     270     # be careful to only apply the affine part that remains.
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/transforms.py:2431, in CompositeGenericTransform.transform_path_non_affine(self, path)
#    2430 elif not self._a.is_affine and self._b.is_affine:
# -> 2431     return self._a.transform_path_non_affine(path)
#    2432 else:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:186, in InterProjectionTransform.transform_path_non_affine(self, src_path)
#     182 # Check whether this transform has the "force_path_ccw" attribute set.
#     183 # This is a cartopy extension to the Transform API to allow finer
#     184 # control of Path orientation handling (Path ordering is not important
#     185 # in matplotlib, but is in Cartopy).
# --> 186 geoms = cpatch.path_to_geos(src_path,
#     187                             getattr(self, 'force_path_ccw', False))
#     189 for geom in geoms:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/cartopy/mpl/patch.py:143, in path_to_geos(path, force_ccw)
#     140 # Split into subarrays such that each subarray consists of connected
#     141 # line segments based on the start of each one being marked by a
#     142 # matplotlib MOVETO code.
# --> 143 verts_split_inds = np.where(path_codes == Path.MOVETO)[0]
#     144 verts_split = np.split(path_verts, verts_split_inds)
#
# File <__array_function__ internals>:177, in where(*args, **kwargs)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 ani.save('v10m_2022heatwave.mp4')
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/animation.py:1077, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1073 savefig_kwargs['transparent'] = False   # just to be safe!
#    1074 # canvas._is_saving = True makes the draw_event animation-starting
#    1075 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1076 # widget (both are likewise done in savefig()).
# -> 1077 with mpl.rc_context({'savefig.bbox': None}), \
#    1078      writer.saving(self._fig, filename, dpi), \
#    1079      cbook._setattr_cm(self._fig.canvas,
#    1080                        _is_saving=True, manager=None):
#    1081     for anim in all_anim:
#    1082         anim._init_draw()  # Clear the initial frame
#
# File /srv/conda/envs/notebook/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/animation.py:233, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     231     yield self
#     232 finally:
# --> 233     self.finish()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/animation.py:347, in MovieWriter.finish(self)
#     343     _log.log(
#     344         logging.WARNING if self._proc.returncode else logging.DEBUG,
#     345         "MovieWriter stderr:\n%s", err)
#     346 if self._proc.returncode:
# --> 347     raise subprocess.CalledProcessError(
#     348         self._proc.returncode, self._proc.args, out, err)
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '500x500', '-pix_fmt', 'rgba', '-r', '5.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', 'v10m_2022heatwave.mp4']' returned non-zero exit status 255.

# %%
Video('t10m_2022heatwave.mp4')
