# %% [markdown]
# # AR Characteristics EDA

# %% [markdown]
# A little EDA to explore any possible patterns in AR characteristics and geographic distributions, etc.

# %%
import xarray as xr
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.util import add_cyclic_point
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from matplotlib import animation
from IPython.display import Video
import pandas as pd
import sklearn.cluster as cluster

# %%
from IPython.display import display, Markdown
import warnings
import os
import requests
import s3fs
import boto3
from subprocess import Popen
from getpass import getpass
from netrc import netrc

# %%
if (boto3.client('s3').meta.region_name == 'us-west-2'):
    display(Markdown('### us-west-2 Region Check: &#x2705;'))
else:
    display(Markdown('### us-west-2 Region Check: &#10060;'))
    raise ValueError('Your notebook is not running inside the AWS us-west-2 region, and will not be able to directly access NASA Earthdata S3 buckets')
# Out:
# ### us-west-2 Region Check: &#x2705;

# %%
urs = 'urs.earthdata.nasa.gov'    # Earthdata URL endpoint for authentication
prompts = ['Enter NASA Earthdata Login Username: ',
           'Enter NASA Earthdata Login Password: ']

netrc_name = ".netrc"

# Determine if netrc file exists, and if so, if it includes NASA Earthdata Login Credentials
try:
    netrcDir = os.path.expanduser(f"~/{netrc_name}")
    # Check credentials against URS, and if username exists
    netrc(netrcDir).authenticators(urs)[0]

# Below, create a netrc file and prompt user for NASA Earthdata Login Username and Password
except FileNotFoundError:
    homeDir = os.path.expanduser("~")
    Popen('touch {0}{2} | echo machine {1} >> {0}{2}'.format(homeDir + os.sep, urs, netrc_name), shell=True)
    Popen('echo login {} >> {}{}'.format(getpass(prompt=prompts[0]), homeDir + os.sep, netrc_name), shell=True)
    Popen('echo \'password {} \'>> {}{}'.format(getpass(prompt=prompts[1]), homeDir + os.sep, netrc_name), shell=True)
    # Set restrictive permissions
    Popen('chmod 0600 {0}{1}'.format(homeDir + os.sep, netrc_name), shell=True)

# %%
gesdisc_s3 = "https://data.gesdisc.earthdata.nasa.gov/s3credentials"

# Define a function for S3 access credentials

def begin_s3_direct_access(url: str=gesdisc_s3):
    response = requests.get(url).json()
    return s3fs.S3FileSystem(key=response['accessKeyId'],
                             secret=response['secretAccessKey'],
                             token=response['sessionToken'],
                             client_kwargs={'region_name':'us-west-2'})

fs = begin_s3_direct_access()

# Check that the file system is intact as an S3FileSystem object, which means that token is valid
# Common causes of rejected S3 access tokens include incorrect passwords stored in the netrc file, or a non-existent netrc file
type(fs)
# Out:
# s3fs.core.S3FileSystem

# %%
links_file = open('/home/jovyan/extreme_antarctic_ARs/data/merra2/subset_M2I1NXASM_5.12.4_20240413_033655_S3URLs.txt')
links_lst = links_file.readlines()
links_lst = [link.strip() for link in links_lst]

# %%
years = np.arange(1980, 2023)
ar_catalog_names = sorted(os.listdir('/home/jovyan/extreme_antarctic_ARs/data/ar_catalogs/'))

# %%
# full range of dates of MERRA2

for i in range(len(ar_catalog_names)):
    
    year = years[i]
    ar_catalog = ar_catalog_names[i]

    

    

    


datasets = []

for link in links_lst:
    
    dat = xr.open_dataset(fs.open(link), decode_cf=True,)
    antarctic_dat = dat.sel(lat = slice(-90.0, -50.0), lon = slice(-180, 179.4))
    sub_dat = antarctic_dat[['TQV']]
    datasets.append(sub_dat)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 7
#       3 datasets = []
#       5 for link in links_lst:
# ----> 7     dat = xr.open_dataset(fs.open(link), decode_cf=True,)
#       8     antarctic_dat = dat.sel(lat = slice(-90.0, -50.0), lon = slice(-180, 179.4))
#       9     sub_dat = antarctic_dat[['TQV']]
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/backends/api.py:573, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     561 decoders = _resolve_decoders_kwargs(
#     562     decode_cf,
#     563     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     569     decode_coords=decode_coords,
#     570 )
#     572 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 573 backend_ds = backend.open_dataset(
#     574     filename_or_obj,
#     575     drop_variables=drop_variables,
#     576     **decoders,
#     577     **kwargs,
#     578 )
#     579 ds = _dataset_from_backend_dataset(
#     580     backend_ds,
#     581     filename_or_obj,
#    (...)
#     591     **kwargs,
#     592 )
#     593 return ds
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/backends/h5netcdf_.py:419, in H5netcdfBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, format, group, lock, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds)
#     405 store = H5NetCDFStore.open(
#     406     filename_or_obj,
#     407     format=format,
#    (...)
#     414     driver_kwds=driver_kwds,
#     415 )
#     417 store_entrypoint = StoreBackendEntrypoint()
# --> 419 ds = store_entrypoint.open_dataset(
#     420     store,
#     421     mask_and_scale=mask_and_scale,
#     422     decode_times=decode_times,
#     423     concat_characters=concat_characters,
#     424     decode_coords=decode_coords,
#     425     drop_variables=drop_variables,
#     426     use_cftime=use_cftime,
#     427     decode_timedelta=decode_timedelta,
#     428 )
#     429 return ds
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/backends/store.py:43, in StoreBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      29 def open_dataset(  # type: ignore[override]  # allow LSP violation, not supporting **kwargs
#      30     self,
#      31     filename_or_obj: str | os.PathLike[Any] | BufferedIOBase | AbstractDataStore,
#    (...)
#      39     decode_timedelta=None,
#      40 ) -> Dataset:
#      41     assert isinstance(filename_or_obj, AbstractDataStore)
# ---> 43     vars, attrs = filename_or_obj.load()
#      44     encoding = filename_or_obj.get_encoding()
#      46     vars, attrs, coord_names = conventions.decode_cf_variables(
#      47         vars,
#      48         attrs,
#    (...)
#      55         decode_timedelta=decode_timedelta,
#      56     )
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/backends/common.py:253, in AbstractDataStore.load(self)
#     230 """
#     231 This loads the variables and attributes simultaneously.
#     232 A centralized loading function makes it easier to create
#    (...)
#     248 are requested, so care should be taken to make sure its fast.
#     249 """
#     250 variables = FrozenDict(
#     251     (_decode_variable_name(k), v) for k, v in self.get_variables().items()
#     252 )
# --> 253 attributes = FrozenDict(self.get_attrs())
#     254 return variables, attributes
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/backends/h5netcdf_.py:243, in H5NetCDFStore.get_attrs(self)
#     242 def get_attrs(self):
# --> 243     return FrozenDict(_read_attributes(self.ds))
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/backends/h5netcdf_.py:67, in _read_attributes(h5netcdf_var)
#      62 def _read_attributes(h5netcdf_var):
#      63     # GH451
#      64     # to ensure conventions decoding works properly on Python 3, decode all
#      65     # bytes attributes to strings
#      66     attrs = {}
# ---> 67     for k, v in h5netcdf_var.attrs.items():
#      68         if k not in ["_FillValue", "missing_value"]:
#      69             if isinstance(v, bytes):
#
# File <frozen _collections_abc>:860, in __iter__(self)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/h5netcdf/attrs.py:92, in Attributes.__iter__(self)
#      91 def __iter__(self):
# ---> 92     for key in self._h5attrs:
#      93         if key not in _HIDDEN_ATTRS:
#      94             yield key
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/h5py/_hl/attrs.py:264, in AttributeManager.__iter__(self)
#     261     else:
#     262         idx_type = h5.INDEX_NAME
# --> 264     h5a.iterate(self._id, iter_cb, index_type=idx_type)
#     266 for name in attrlist:
#     267     yield name
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5a.pyx:293, in h5py.h5a.iterate()
#
# File h5py/h5fd.pyx:163, in h5py.h5fd.H5FD_fileobj_read()
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/fsspec/spec.py:1800, in AbstractBufferedFile.readinto(self, b)
#    1795 """mirrors builtin file's readinto method
#    1796
#    1797 https://docs.python.org/3/library/io.html#io.RawIOBase.readinto
#    1798 """
#    1799 out = memoryview(b).cast("B")
# -> 1800 data = self.read(out.nbytes)
#    1801 out[: len(data)] = data
#    1802 return len(data)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/fsspec/spec.py:1790, in AbstractBufferedFile.read(self, length)
#    1787 if length == 0:
#    1788     # don't even bother calling fetch
#    1789     return b""
# -> 1790 out = self.cache._fetch(self.loc, self.loc + length)
#    1791 self.loc += len(out)
#    1792 return out
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/fsspec/caching.py:156, in ReadAheadCache._fetch(self, start, end)
#     154     part = b""
#     155 end = min(self.size, end + self.blocksize)
# --> 156 self.cache = self.fetcher(start, end)  # new block replaces old
#     157 self.start = start
#     158 self.end = self.start + len(self.cache)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/s3fs/core.py:2185, in S3File._fetch_range(self, start, end)
#    2183 def _fetch_range(self, start, end):
#    2184     try:
# -> 2185         return _fetch_range(
#    2186             self.fs,
#    2187             self.bucket,
#    2188             self.key,
#    2189             self.version_id,
#    2190             start,
#    2191             end,
#    2192             req_kw=self.req_kw,
#    2193         )
#    2195     except OSError as ex:
#    2196         if ex.args[0] == errno.EINVAL and "pre-conditions" in ex.args[1]:
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/s3fs/core.py:2348, in _fetch_range(fs, bucket, key, version_id, start, end, req_kw)
#    2346     return b""
#    2347 logger.debug("Fetch: %s/%s, %s-%s", bucket, key, start, end)
# -> 2348 return sync(fs.loop, _inner_fetch, fs, bucket, key, version_id, start, end, req_kw)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/fsspec/asyn.py:94, in sync(loop, func, timeout, *args, **kwargs)
#      91 asyncio.run_coroutine_threadsafe(_runner(event, coro, result, timeout), loop)
#      92 while True:
#      93     # this loops allows thread to get interrupted
# ---> 94     if event.wait(1):
#      95         break
#      96     if timeout is not None:
#
# File /srv/conda/envs/notebook/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /srv/conda/envs/notebook/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
path = '~/extreme_antarctic_ARs/data/ar_catalogs/'
fn = 'MERRA2.ar_tag.Wille_v2.4_vIVT.3hourly.20220101-20221231.nc'
ar_catalog = xr.open_mfdataset(path+fn)
ar_binary_tag = ar_catalog.ar_binary_tag
#total_dat = xr.merge([ar_catalog, tot_dataset], join='inner')

# %%
ar_binary_tag
# Out:
# <xarray.DataArray 'ar_binary_tag' (time: 2920, lat: 361, lon: 576)> Size: 607MB
# dask.array<open_dataset-ar_binary_tag, shape=(2920, 361, 576), dtype=int8, chunksize=(1, 361, 576), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 3kB -90.0 -89.5 -89.0 -88.5 ... 88.5 89.0 89.5 90.0
#   * lon      (lon) float64 5kB -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * time     (time) datetime64[ns] 23kB 2022-01-01 ... 2022-12-31T21:00:00
# Attributes:
#     scheme:        Wille_vIVT
#     description:   Binary indicator of atmospheric river using vIVT
#     version:       2.4
#     credits:       Developed by Jonathan D. Wille, Ambroise Dufour, Jai Chowd...
#     cell_methods:  time: mean

# %%
# clustering ARs using DBScan

# %% [markdown]
# ## Antarctic-wide
