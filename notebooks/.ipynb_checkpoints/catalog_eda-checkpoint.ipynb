# %% [markdown]
# # Catalog EDA

# %% [markdown]
# Doing some exploratory data analysis with my newly constructed catalog!

# %%
import xarray as xr
import pandas as pd
from pathlib import Path
import os
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

repo_dir = str(Path(os.getcwd()).parents[0])
os.chdir(repo_dir + '/scripts/')
from utils import display_catalog

# %%
# loading up the catalog
catalog = pd.read_hdf('~/extreme_antarctic_ARs/data/landfalling_storm_quantities_df.h5')
catalog = catalog[catalog.landfalling_SLP < 10**7]

# %%
saveable = catalog.loc[:, catalog.columns != 'data_array']
saveable['duration'] = saveable['duration']/pd.Timedelta(1, 'h')
saveable = saveable.loc[:, saveable.columns != 'start_time']
saveable = saveable.loc[:, saveable.columns != 'end_time']
saveable.to_csv('~/extreme_antarctic_ARs/data/ar_database/landfalling_df_no_da.csv')
# Out:
# /tmp/ipykernel_97941/3364738339.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   saveable['duration'] = saveable['duration']/pd.Timedelta(1, 'h')

# %%
display_catalog(catalog, 10)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b62b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b62b7_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_b62b7_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_b62b7_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_b62b7_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_b62b7_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_b62b7_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_b62b7_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_b62b7_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_b62b7_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_b62b7_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_b62b7_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_b62b7_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_b62b7_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_b62b7_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_b62b7_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_b62b7_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_b62b7_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_b62b7_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_b62b7_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_b62b7_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_b62b7_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_b62b7_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_b62b7_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_b62b7_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_b62b7_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_b62b7_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_b62b7_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b62b7_level0_row0" class="row_heading level0 row0" >2733</th>
#       <td id="T_b62b7_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_b62b7_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_b62b7_row0_col2" class="data row0 col2" >1219813.707482</td>
#       <td id="T_b62b7_row0_col3" class="data row0 col3" >1188527.781133</td>
#       <td id="T_b62b7_row0_col4" class="data row0 col4" >567878.092915</td>
#       <td id="T_b62b7_row0_col5" class="data row0 col5" >141969.523229</td>
#       <td id="T_b62b7_row0_col6" class="data row0 col6" >0 days 06:00:00</td>
#       <td id="T_b62b7_row0_col7" class="data row0 col7" >1995-01-07 03:00:00</td>
#       <td id="T_b62b7_row0_col8" class="data row0 col8" >1995-01-07 06:00:00</td>
#       <td id="T_b62b7_row0_col9" class="data row0 col9" >-76.000000</td>
#       <td id="T_b62b7_row0_col10" class="data row0 col10" >274.629913</td>
#       <td id="T_b62b7_row0_col11" class="data row0 col11" >0.853522</td>
#       <td id="T_b62b7_row0_col12" class="data row0 col12" >8.889969</td>
#       <td id="T_b62b7_row0_col13" class="data row0 col13" >2.709316</td>
#       <td id="T_b62b7_row0_col14" class="data row0 col14" >10.033691</td>
#       <td id="T_b62b7_row0_col15" class="data row0 col15" >5.324115</td>
#       <td id="T_b62b7_row0_col16" class="data row0 col16" >14.543134</td>
#       <td id="T_b62b7_row0_col17" class="data row0 col17" >10.465161</td>
#       <td id="T_b62b7_row0_col18" class="data row0 col18" >20.789228</td>
#       <td id="T_b62b7_row0_col19" class="data row0 col19" >97207.593750</td>
#       <td id="T_b62b7_row0_col20" class="data row0 col20" >7.346375</td>
#       <td id="T_b62b7_row0_col21" class="data row0 col21" >56.887406</td>
#       <td id="T_b62b7_row0_col22" class="data row0 col22" >179.231766</td>
#       <td id="T_b62b7_row0_col23" class="data row0 col23" >138.832279</td>
#       <td id="T_b62b7_row0_col24" class="data row0 col24" >347.207367</td>
#       <td id="T_b62b7_row0_col25" class="data row0 col25" >96729290706.278900</td>
#       <td id="T_b62b7_row0_col26" class="data row0 col26" >1231218542483.822021</td>
#     </tr>
#     <tr>
#       <th id="T_b62b7_level0_row1" class="row_heading level0 row1" >2735</th>
#       <td id="T_b62b7_row1_col0" class="data row1 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_b62b7_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_b62b7_row1_col2" class="data row1 col2" >964372.186669</td>
#       <td id="T_b62b7_row1_col3" class="data row1 col3" >795660.065030</td>
#       <td id="T_b62b7_row1_col4" class="data row1 col4" >58952.144193</td>
#       <td id="T_b62b7_row1_col5" class="data row1 col5" >29476.072097</td>
#       <td id="T_b62b7_row1_col6" class="data row1 col6" >0 days 12:00:00</td>
#       <td id="T_b62b7_row1_col7" class="data row1 col7" >1995-01-08 21:00:00</td>
#       <td id="T_b62b7_row1_col8" class="data row1 col8" >1995-01-09 06:00:00</td>
#       <td id="T_b62b7_row1_col9" class="data row1 col9" >-71.500000</td>
#       <td id="T_b62b7_row1_col10" class="data row1 col10" >272.077332</td>
#       <td id="T_b62b7_row1_col11" class="data row1 col11" >-3.792203</td>
#       <td id="T_b62b7_row1_col12" class="data row1 col12" >1.517767</td>
#       <td id="T_b62b7_row1_col13" class="data row1 col13" >8.508035</td>
#       <td id="T_b62b7_row1_col14" class="data row1 col14" >15.313753</td>
#       <td id="T_b62b7_row1_col15" class="data row1 col15" >7.438242</td>
#       <td id="T_b62b7_row1_col16" class="data row1 col16" >9.868498</td>
#       <td id="T_b62b7_row1_col17" class="data row1 col17" >12.381610</td>
#       <td id="T_b62b7_row1_col18" class="data row1 col18" >23.477619</td>
#       <td id="T_b62b7_row1_col19" class="data row1 col19" >96750.773438</td>
#       <td id="T_b62b7_row1_col20" class="data row1 col20" >1.650452</td>
#       <td id="T_b62b7_row1_col21" class="data row1 col21" >48.193964</td>
#       <td id="T_b62b7_row1_col22" class="data row1 col22" >96.928833</td>
#       <td id="T_b62b7_row1_col23" class="data row1 col23" >176.964111</td>
#       <td id="T_b62b7_row1_col24" class="data row1 col24" >377.114990</td>
#       <td id="T_b62b7_row1_col25" class="data row1 col25" >0.000000</td>
#       <td id="T_b62b7_row1_col26" clas

# %% [markdown]
# ## Single Variable Plots

# %% [markdown]
# ### Covariates

# %%
sns.histplot(data = catalog.duration/pd.Timedelta(1, 'd'), bins=15);
plt.title('Storm Durations');
plt.xlabel('Duration (days)');

# %% [markdown]
# **Fun Fact**: the longest AR in the catalog is one that's mentioned in *Climatology and surface impacts of atmospheric rivers on West Antarctica* by Maclennan et al. (2023). Although this paper calls it a family event with three ARs present.. did my catalog group them all together?

# %%
display_catalog(catalog.loc[[catalog.duration.idxmax()]])
# Out:
# <style type="text/css">
# </style>
# <table id="T_54fa0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54fa0_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_54fa0_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_54fa0_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_54fa0_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_54fa0_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_54fa0_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_54fa0_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_54fa0_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_54fa0_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_54fa0_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_54fa0_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_54fa0_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_54fa0_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_54fa0_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_54fa0_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_54fa0_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_54fa0_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_54fa0_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_54fa0_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_54fa0_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_54fa0_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_54fa0_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_54fa0_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_54fa0_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_54fa0_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_54fa0_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_54fa0_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54fa0_level0_row0" class="row_heading level0 row0" >7676</th>
#       <td id="T_54fa0_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_54fa0_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_54fa0_row0_col2" class="data row0 col2" >2935928.746476</td>
#       <td id="T_54fa0_row0_col3" class="data row0 col3" >1817583.000278</td>
#       <td id="T_54fa0_row0_col4" class="data row0 col4" >198991.368191</td>
#       <td id="T_54fa0_row0_col5" class="data row0 col5" >1766048.392699</td>
#       <td id="T_54fa0_row0_col6" class="data row0 col6" >10 days 06:00:00</td>
#       <td id="T_54fa0_row0_col7" class="data row0 col7" >2020-01-30 06:00:00</td>
#       <td id="T_54fa0_row0_col8" class="data row0 col8" >2020-02-09 09:00:00</td>
#       <td id="T_54fa0_row0_col9" class="data row0 col9" >-85.000000</td>
#       <td id="T_54fa0_row0_col10" class="data row0 col10" >275.600861</td>
#       <td id="T_54fa0_row0_col11" class="data row0 col11" >3.744407</td>
#       <td id="T_54fa0_row0_col12" class="data row0 col12" >18.152763</td>
#       <td id="T_54fa0_row0_col13" class="data row0 col13" >10.325054</td>
#       <td id="T_54fa0_row0_col14" class="data row0 col14" >21.360769</td>
#       <td id="T_54fa0_row0_col15" class="data row0 col15" >9.810604</td>
#       <td id="T_54fa0_row0_col16" class="data row0 col16" >24.588255</td>
#       <td id="T_54fa0_row0_col17" class="data row0 col17" >22.135467</td>
#       <td id="T_54fa0_row0_col18" class="data row0 col18" >44.086376</td>
#       <td id="T_54fa0_row0_col19" class="data row0 col19" >95647.390625</td>
#       <td id="T_54fa0_row0_col20" class="data row0 col20" >16.770645</td>
#       <td id="T_54fa0_row0_col21" class="data row0 col21" >133.558426</td>
#       <td id="T_54fa0_row0_col22" class="data row0 col22" >482.416870</td>
#       <td id="T_54fa0_row0_col23" class="data row0 col23" >433.960911</td>
#       <td id="T_54fa0_row0_col24" class="data row0 col24" >989.393433</td>
#       <td id="T_54fa0_row0_col25" class="data row0 col25" >435797848309.754761</td>
#       <td id="T_54fa0_row0_col26" class="data row0 col26" >26569733202338.609375</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=catalog, x='max_area', bins=20);
plt.title('Area at time of Greatest Extent');
plt.xlabel('Area (km^2)');

# %%
sns.histplot(data=catalog, x='max_vIVT', bins=20);
plt.title('Max vIVT of Each Storm');
plt.xlabel('vIVT');

# %%
display_catalog(catalog.loc[[catalog.max_vIVT.idxmax()]])
# Out:
# <style type="text/css">
# </style>
# <table id="T_1f615">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f615_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_1f615_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_1f615_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_1f615_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_1f615_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_1f615_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_1f615_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_1f615_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_1f615_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_1f615_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_1f615_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_1f615_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_1f615_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_1f615_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_1f615_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_1f615_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_1f615_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_1f615_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_1f615_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_1f615_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_1f615_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_1f615_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_1f615_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_1f615_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_1f615_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_1f615_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_1f615_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f615_level0_row0" class="row_heading level0 row0" >6601</th>
#       <td id="T_1f615_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_1f615_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_1f615_row0_col2" class="data row0 col2" >2891160.164788</td>
#       <td id="T_1f615_row0_col3" class="data row0 col3" >2287240.165967</td>
#       <td id="T_1f615_row0_col4" class="data row0 col4" >19407.115523</td>
#       <td id="T_1f615_row0_col5" class="data row0 col5" >38814.231046</td>
#       <td id="T_1f615_row0_col6" class="data row0 col6" >2 days 12:00:00</td>
#       <td id="T_1f615_row0_col7" class="data row0 col7" >2015-02-03 03:00:00</td>
#       <td id="T_1f615_row0_col8" class="data row0 col8" >2015-02-05 12:00:00</td>
#       <td id="T_1f615_row0_col9" class="data row0 col9" >-69.500000</td>
#       <td id="T_1f615_row0_col10" class="data row0 col10" >267.807129</td>
#       <td id="T_1f615_row0_col11" class="data row0 col11" >-7.612618</td>
#       <td id="T_1f615_row0_col12" class="data row0 col12" >-0.000000</td>
#       <td id="T_1f615_row0_col13" class="data row0 col13" >9.980032</td>
#       <td id="T_1f615_row0_col14" class="data row0 col14" >26.922260</td>
#       <td id="T_1f615_row0_col15" class="data row0 col15" >7.365378</td>
#       <td id="T_1f615_row0_col16" class="data row0 col16" >14.359858</td>
#       <td id="T_1f615_row0_col17" class="data row0 col17" >27.593810</td>
#       <td id="T_1f615_row0_col18" class="data row0 col18" >51.842247</td>
#       <td id="T_1f615_row0_col19" class="data row0 col19" >95969.234375</td>
#       <td id="T_1f615_row0_col20" class="data row0 col20" >2.336349</td>
#       <td id="T_1f615_row0_col21" class="data row0 col21" >59.652332</td>
#       <td id="T_1f615_row0_col22" class="data row0 col22" >146.783920</td>
#       <td id="T_1f615_row0_col23" class="data row0 col23" >589.657774</td>
#       <td id="T_1f615_row0_col24" class="data row0 col24" >1988.771851</td>
#       <td id="T_1f615_row0_col25" class="data row0 col25" >2862309538.008983</td>
#       <td id="T_1f615_row0_col26" class="data row0 col26" >2713192223567.283691</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=catalog, x='max_vIVT_ais', bins=20);
plt.title('Max vIVT of Each Storm over AIS');
plt.xlabel('vIVT');

# %% [markdown]
# **Fun Fact**: the storm with the greatest landfalling vIVT was the same AR from Gorodetskaya.

# %%
display_catalog(catalog.loc[[catalog.max_vIVT_ais.idxmax()]])
# Out:
# <style type="text/css">
# </style>
# <table id="T_b6ab1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6ab1_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_b6ab1_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_b6ab1_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_b6ab1_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_b6ab1_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_b6ab1_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_b6ab1_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_b6ab1_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_b6ab1_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_b6ab1_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_b6ab1_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_b6ab1_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_b6ab1_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_b6ab1_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_b6ab1_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_b6ab1_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_b6ab1_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_b6ab1_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_b6ab1_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_b6ab1_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_b6ab1_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_b6ab1_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_b6ab1_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_b6ab1_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_b6ab1_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_b6ab1_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_b6ab1_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6ab1_level0_row0" class="row_heading level0 row0" >8117</th>
#       <td id="T_b6ab1_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_b6ab1_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_b6ab1_row0_col2" class="data row0 col2" >3877096.641947</td>
#       <td id="T_b6ab1_row0_col3" class="data row0 col3" >2475621.043861</td>
#       <td id="T_b6ab1_row0_col4" class="data row0 col4" >714979.068131</td>
#       <td id="T_b6ab1_row0_col5" class="data row0 col5" >3038661.039558</td>
#       <td id="T_b6ab1_row0_col6" class="data row0 col6" >4 days 06:00:00</td>
#       <td id="T_b6ab1_row0_col7" class="data row0 col7" >2022-02-05 03:00:00</td>
#       <td id="T_b6ab1_row0_col8" class="data row0 col8" >2022-02-09 06:00:00</td>
#       <td id="T_b6ab1_row0_col9" class="data row0 col9" >-85.000000</td>
#       <td id="T_b6ab1_row0_col10" class="data row0 col10" >279.027313</td>
#       <td id="T_b6ab1_row0_col11" class="data row0 col11" >2.962659</td>
#       <td id="T_b6ab1_row0_col12" class="data row0 col12" >17.935772</td>
#       <td id="T_b6ab1_row0_col13" class="data row0 col13" >8.916690</td>
#       <td id="T_b6ab1_row0_col14" class="data row0 col14" >20.950256</td>
#       <td id="T_b6ab1_row0_col15" class="data row0 col15" >10.689799</td>
#       <td id="T_b6ab1_row0_col16" class="data row0 col16" >27.609982</td>
#       <td id="T_b6ab1_row0_col17" class="data row0 col17" >20.262910</td>
#       <td id="T_b6ab1_row0_col18" class="data row0 col18" >45.593719</td>
#       <td id="T_b6ab1_row0_col19" class="data row0 col19" >97738.375000</td>
#       <td id="T_b6ab1_row0_col20" class="data row0 col20" >20.089249</td>
#       <td id="T_b6ab1_row0_col21" class="data row0 col21" >155.249612</td>
#       <td id="T_b6ab1_row0_col22" class="data row0 col22" >748.183411</td>
#       <td id="T_b6ab1_row0_col23" class="data row0 col23" >392.403089</td>
#       <td id="T_b6ab1_row0_col24" class="data row0 col24" >1125.843506</td>
#       <td id="T_b6ab1_row0_col25" class="data row0 col25" >3926887079388.039062</td>
#       <td id="T_b6ab1_row0_col26" class="data row0 col26" >37590032264497.140625</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=catalog, x='max_IWV', bins=20);
plt.title('Max IWV');
plt.xlabel('IWV');

# %%
sns.histplot(data=catalog, x='max_IWV_ais', bins=20);
plt.title('Max IWV over AIS');
plt.xlabel('IWV');

# %%
display_catalog(catalog.loc[[catalog.max_IWV_ais.idxmax()]])
# Out:
# <style type="text/css">
# </style>
# <table id="T_b91fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b91fa_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_b91fa_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_b91fa_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_b91fa_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_b91fa_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_b91fa_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_b91fa_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_b91fa_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_b91fa_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_b91fa_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_b91fa_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_b91fa_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_b91fa_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_b91fa_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_b91fa_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_b91fa_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_b91fa_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_b91fa_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_b91fa_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_b91fa_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_b91fa_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_b91fa_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_b91fa_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_b91fa_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_b91fa_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_b91fa_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_b91fa_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b91fa_level0_row0" class="row_heading level0 row0" >4576</th>
#       <td id="T_b91fa_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_b91fa_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_b91fa_row0_col2" class="data row0 col2" >3061358.166454</td>
#       <td id="T_b91fa_row0_col3" class="data row0 col3" >2066635.799071</td>
#       <td id="T_b91fa_row0_col4" class="data row0 col4" >501973.247743</td>
#       <td id="T_b91fa_row0_col5" class="data row0 col5" >1568666.399197</td>
#       <td id="T_b91fa_row0_col6" class="data row0 col6" >3 days 03:00:00</td>
#       <td id="T_b91fa_row0_col7" class="data row0 col7" >2005-02-08 12:00:00</td>
#       <td id="T_b91fa_row0_col8" class="data row0 col8" >2005-02-11 12:00:00</td>
#       <td id="T_b91fa_row0_col9" class="data row0 col9" >-85.000000</td>
#       <td id="T_b91fa_row0_col10" class="data row0 col10" >278.481018</td>
#       <td id="T_b91fa_row0_col11" class="data row0 col11" >2.071489</td>
#       <td id="T_b91fa_row0_col12" class="data row0 col12" >23.423197</td>
#       <td id="T_b91fa_row0_col13" class="data row0 col13" >9.509968</td>
#       <td id="T_b91fa_row0_col14" class="data row0 col14" >23.423197</td>
#       <td id="T_b91fa_row0_col15" class="data row0 col15" >9.604741</td>
#       <td id="T_b91fa_row0_col16" class="data row0 col16" >29.251392</td>
#       <td id="T_b91fa_row0_col17" class="data row0 col17" >22.385771</td>
#       <td id="T_b91fa_row0_col18" class="data row0 col18" >48.787693</td>
#       <td id="T_b91fa_row0_col19" class="data row0 col19" >96808.281250</td>
#       <td id="T_b91fa_row0_col20" class="data row0 col20" >17.248505</td>
#       <td id="T_b91fa_row0_col21" class="data row0 col21" >140.250768</td>
#       <td id="T_b91fa_row0_col22" class="data row0 col22" >705.529114</td>
#       <td id="T_b91fa_row0_col23" class="data row0 col23" >403.804376</td>
#       <td id="T_b91fa_row0_col24" class="data row0 col24" >1005.653809</td>
#       <td id="T_b91fa_row0_col25" class="data row0 col25" >1922697885728.063232</td>
#       <td id="T_b91fa_row0_col26" class="data row0 col26" >30737799330482.054688</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=catalog, x='max_V10m', bins=20);
plt.title('Max V10m');
plt.xlabel('V10m (m/s)');

# %%
sns.histplot(data=catalog, x='max_V10m_ais', bins=20);
plt.title('Max V10m');
plt.xlabel('V10m (m/s)');

# %%
display_catalog(catalog.loc[[catalog.max_V10m_ais.idxmax()]])
# Out:
# <style type="text/css">
# </style>
# <table id="T_443d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_443d4_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_443d4_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_443d4_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_443d4_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_443d4_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_443d4_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_443d4_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_443d4_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_443d4_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_443d4_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_443d4_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_443d4_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_443d4_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_443d4_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_443d4_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_443d4_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_443d4_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_443d4_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_443d4_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_443d4_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_443d4_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_443d4_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_443d4_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_443d4_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_443d4_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_443d4_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_443d4_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_443d4_level0_row0" class="row_heading level0 row0" >6271</th>
#       <td id="T_443d4_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_443d4_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_443d4_row0_col2" class="data row0 col2" >3545445.387480</td>
#       <td id="T_443d4_row0_col3" class="data row0 col3" >2627716.884498</td>
#       <td id="T_443d4_row0_col4" class="data row0 col4" >730981.834967</td>
#       <td id="T_443d4_row0_col5" class="data row0 col5" >2192945.504901</td>
#       <td id="T_443d4_row0_col6" class="data row0 col6" >3 days 00:00:00</td>
#       <td id="T_443d4_row0_col7" class="data row0 col7" >2013-05-30 21:00:00</td>
#       <td id="T_443d4_row0_col8" class="data row0 col8" >2013-06-02 18:00:00</td>
#       <td id="T_443d4_row0_col9" class="data row0 col9" >-85.000000</td>
#       <td id="T_443d4_row0_col10" class="data row0 col10" >270.485077</td>
#       <td id="T_443d4_row0_col11" class="data row0 col11" >12.917297</td>
#       <td id="T_443d4_row0_col12" class="data row0 col12" >39.214401</td>
#       <td id="T_443d4_row0_col13" class="data row0 col13" >12.740975</td>
#       <td id="T_443d4_row0_col14" class="data row0 col14" >39.214401</td>
#       <td id="T_443d4_row0_col15" class="data row0 col15" >3.289652</td>
#       <td id="T_443d4_row0_col16" class="data row0 col16" >10.429421</td>
#       <td id="T_443d4_row0_col17" class="data row0 col17" >13.158979</td>
#       <td id="T_443d4_row0_col18" class="data row0 col18" >38.388889</td>
#       <td id="T_443d4_row0_col19" class="data row0 col19" >94864.023438</td>
#       <td id="T_443d4_row0_col20" class="data row0 col20" >33.251129</td>
#       <td id="T_443d4_row0_col21" class="data row0 col21" >80.041724</td>
#       <td id="T_443d4_row0_col22" class="data row0 col22" >344.723297</td>
#       <td id="T_443d4_row0_col23" class="data row0 col23" >311.230932</td>
#       <td id="T_443d4_row0_col24" class="data row0 col24" >1306.999756</td>
#       <td id="T_443d4_row0_col25" class="data row0 col25" >0.000000</td>
#       <td id="T_443d4_row0_col26" class="data row0 col26" >22663150264752.027344</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=catalog, x='cumulative_landfalling_area', bins=20);
plt.title('Landfalling Impact Metric');
plt.xlabel('Landfalling Area, Cumulative over Time (km^2 day)');

# %% [markdown]
# **Fun Fact**: AR with the highest value of this impact metric is the 2022 heatwave AR!

# %%
display_catalog(catalog.loc[[catalog.cumulative_landfalling_area.idxmax()]])
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba5a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba5a8_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_ba5a8_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_ba5a8_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_ba5a8_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_ba5a8_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_ba5a8_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_ba5a8_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_ba5a8_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_ba5a8_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_ba5a8_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_ba5a8_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_ba5a8_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_ba5a8_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_ba5a8_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_ba5a8_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_ba5a8_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_ba5a8_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_ba5a8_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_ba5a8_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_ba5a8_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_ba5a8_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_ba5a8_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_ba5a8_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_ba5a8_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_ba5a8_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_ba5a8_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_ba5a8_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba5a8_level0_row0" class="row_heading level0 row0" >8137</th>
#       <td id="T_ba5a8_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_ba5a8_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_ba5a8_row0_col2" class="data row0 col2" >6299194.344214</td>
#       <td id="T_ba5a8_row0_col3" class="data row0 col3" >3403828.602753</td>
#       <td id="T_ba5a8_row0_col4" class="data row0 col4" >1569910.210468</td>
#       <td id="T_ba5a8_row0_col5" class="data row0 col5" >7457073.499721</td>
#       <td id="T_ba5a8_row0_col6" class="data row0 col6" >4 days 18:00:00</td>
#       <td id="T_ba5a8_row0_col7" class="data row0 col7" >2022-03-13 15:00:00</td>
#       <td id="T_ba5a8_row0_col8" class="data row0 col8" >2022-03-18 06:00:00</td>
#       <td id="T_ba5a8_row0_col9" class="data row0 col9" >-85.000000</td>
#       <td id="T_ba5a8_row0_col10" class="data row0 col10" >278.642639</td>
#       <td id="T_ba5a8_row0_col11" class="data row0 col11" >0.531637</td>
#       <td id="T_ba5a8_row0_col12" class="data row0 col12" >15.266479</td>
#       <td id="T_ba5a8_row0_col13" class="data row0 col13" >8.315104</td>
#       <td id="T_ba5a8_row0_col14" class="data row0 col14" >21.859558</td>
#       <td id="T_ba5a8_row0_col15" class="data row0 col15" >4.008752</td>
#       <td id="T_ba5a8_row0_col16" class="data row0 col16" >23.074251</td>
#       <td id="T_ba5a8_row0_col17" class="data row0 col17" >16.122986</td>
#       <td id="T_ba5a8_row0_col18" class="data row0 col18" >45.662140</td>
#       <td id="T_ba5a8_row0_col19" class="data row0 col19" >96281.687500</td>
#       <td id="T_ba5a8_row0_col20" class="data row0 col20" >40.972366</td>
#       <td id="T_ba5a8_row0_col21" class="data row0 col21" >63.922712</td>
#       <td id="T_ba5a8_row0_col22" class="data row0 col22" >482.539856</td>
#       <td id="T_ba5a8_row0_col23" class="data row0 col23" >351.682389</td>
#       <td id="T_ba5a8_row0_col24" class="data row0 col24" >1251.982056</td>
#       <td id="T_ba5a8_row0_col25" class="data row0 col25" >679245650359.845337</td>
#       <td id="T_ba5a8_row0_col26" class="data row0 col26" >72319870204593.062500</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=catalog, x='max_south_extent', bins=20);
plt.title('Max Southward Extent of ARs');
plt.xlabel('Max Southward Extent (degrees)');

# %% [markdown]
# ### Impact/Outcome Variables

# %%
sns.histplot(data=catalog, x='max_T2m_ais', bins=20);
plt.title('Max 2m Temp over AIS');
plt.xlabel('Max Temperature (K)');

# %%
above_freezing = catalog.loc[catalog.max_T2m_ais >= 273.15]
sns.histplot(x=above_freezing.max_T2m_ais, bins=10);
plt.title('Max 2m Temp over AIS (above freezing)');
plt.xlabel('Max Temperature (K)');

# %% [markdown]
# **Fun Fact**: the storm with the highest landfalling temperature on the AIS was an AR that caused the Larsen A ice shelf collapse!

# %%
display_catalog(catalog.loc[catalog.max_T2m_ais.idxmax()])
# Out:
# <style type="text/css">
# </style>
# <table id="T_ca823">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca823_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_ca823_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_ca823_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_ca823_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_ca823_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_ca823_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_ca823_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_ca823_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_ca823_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_ca823_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_ca823_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_ca823_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_ca823_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_ca823_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_ca823_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_ca823_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_ca823_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_ca823_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_ca823_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_ca823_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_ca823_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_ca823_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_ca823_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_ca823_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_ca823_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_ca823_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_ca823_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca823_level0_row0" class="row_heading level0 row0" >2740</th>
#       <td id="T_ca823_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_ca823_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_ca823_row0_col2" class="data row0 col2" >2262846.280307</td>
#       <td id="T_ca823_row0_col3" class="data row0 col3" >2112468.956708</td>
#       <td id="T_ca823_row0_col4" class="data row0 col4" >105471.757808</td>
#       <td id="T_ca823_row0_col5" class="data row0 col5" >118655.727534</td>
#       <td id="T_ca823_row0_col6" class="data row0 col6" >1 days 03:00:00</td>
#       <td id="T_ca823_row0_col7" class="data row0 col7" >1995-01-24 00:00:00</td>
#       <td id="T_ca823_row0_col8" class="data row0 col8" >1995-01-25 00:00:00</td>
#       <td id="T_ca823_row0_col9" class="data row0 col9" >-76.500000</td>
#       <td id="T_ca823_row0_col10" class="data row0 col10" >279.203552</td>
#       <td id="T_ca823_row0_col11" class="data row0 col11" >6.461016</td>
#       <td id="T_ca823_row0_col12" class="data row0 col12" >19.237509</td>
#       <td id="T_ca823_row0_col13" class="data row0 col13" >11.773177</td>
#       <td id="T_ca823_row0_col14" class="data row0 col14" >21.582748</td>
#       <td id="T_ca823_row0_col15" class="data row0 col15" >14.506771</td>
#       <td id="T_ca823_row0_col16" class="data row0 col16" >25.030884</td>
#       <td id="T_ca823_row0_col17" class="data row0 col17" >23.756501</td>
#       <td id="T_ca823_row0_col18" class="data row0 col18" >39.180656</td>
#       <td id="T_ca823_row0_col19" class="data row0 col19" >94993.968750</td>
#       <td id="T_ca823_row0_col20" class="data row0 col20" >9.236847</td>
#       <td id="T_ca823_row0_col21" class="data row0 col21" >263.376383</td>
#       <td id="T_ca823_row0_col22" class="data row0 col22" >626.006409</td>
#       <td id="T_ca823_row0_col23" class="data row0 col23" >494.445933</td>
#       <td id="T_ca823_row0_col24" class="data row0 col24" >982.367371</td>
#       <td id="T_ca823_row0_col25" class="data row0 col25" >1037725997306.208862</td>
#       <td id="T_ca823_row0_col26" class="data row0 col26" >5195927241157.639648</td>
#     </tr>
#     <tr>
#       <th id="T_ca823_level0_row1" class="row_heading level0 row1" >2740</th>
#       <td id="T_ca823_row1_col0" class="data row1 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_ca823_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_ca823_row1_col2" class="data row1 col2" >2262846.280307</td>
#       <td id="T_ca823_row1_col3" class="data row1 col3" >2112468.956708</td>
#       <td id="T_ca823_row1_col4" class="data row1 col4" >105471.757808</td>
#       <td id="T_ca823_row1_col5" class="data row1 col5" >118655.727534</td>
#       <td id="T_ca823_row1_col6" class="data row1 col6" >1 days 03:00:00</td>
#       <td id="T_ca823_row1_col7" class="data row1 col7" >1995-01-24 00:00:00</td>
#       <td id="T_ca823_row1_col8" class="data row1 col8" >1995-01-25 00:00:00</td>
#       <td id="T_ca823_row1_col9" class="data row1 col9" >-76.500000</td>
#       <td id="T_ca823_row1_col10" class="data row1 col10" >279.203552</td>
#       <td id="T_ca823_row1_col11" class="data row1 col11" >6.461016</td>
#       <td id="T_ca823_row1_col12" class="data row1 col12" >19.237509</td>
#       <td id="T_ca823_row1_col13" class="data row1 col13" >11.773177</td>
#       <td id="T_ca823_row1_col14" class="data row1 col14" >21.582748</td>
#       <td id="T_ca823_row1_col15" class="data row1 col15" >14.506771</td>
#       <td id="T_ca823_row1_col16" class="data row1 col16" >25.030884</td>
#       <td id="T_ca823_row1_col17" class="data row1 col17" >23.756501</td>
#       <td id="T_ca823_row1_col18" class="data row1 col18" >39.180656</td>
#       <td id="T_ca823_row1_col19" class="data row1 col19" >94993.968750</td>
#       <td id="T_ca823_row1_col20" class="data row1 col20" >9.236847</td>
#       <td id="T_ca823_row1_col21" class="data row1 col21" >263.376383</td>
#       <td id="T_ca823_row1_col22" class="data row1 col22" >626.006409</td>
#       <td id="T_ca823_row1_col23" class="data row1 col23" >494.445933</td>
#       <td id="T_ca823_row1_col24" class="data row1 col24" >982.367371</td>
#       <td id="T_ca823_row1_col25" class="data row1 col25" >1037725997306.208862</td>
#       <td i

# %%
sns.histplot(data=catalog, x='max_T2M_anomaly_ais', bins=10);
plt.title('Max 2m Temp Anomaly over AIS');
plt.xlabel('2m Temp Anomaly (K)');

# %% [markdown]
# **Fun Fact**: the storm with the highest max temp anomaly over the ice sheet was the Antarctic AR!

# %%
display_catalog(catalog.loc[[catalog.max_T2M_anomaly_ais.idxmax()]])
# Out:
# <style type="text/css">
# </style>
# <table id="T_c7b54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7b54_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_c7b54_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_c7b54_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_c7b54_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_c7b54_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_c7b54_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_c7b54_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_c7b54_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_c7b54_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_c7b54_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_c7b54_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_c7b54_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_c7b54_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_c7b54_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_c7b54_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_c7b54_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_c7b54_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_c7b54_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_c7b54_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_c7b54_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_c7b54_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_c7b54_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_c7b54_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_c7b54_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_c7b54_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_c7b54_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_c7b54_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7b54_level0_row0" class="row_heading level0 row0" >8137</th>
#       <td id="T_c7b54_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_c7b54_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_c7b54_row0_col2" class="data row0 col2" >6299194.344214</td>
#       <td id="T_c7b54_row0_col3" class="data row0 col3" >3403828.602753</td>
#       <td id="T_c7b54_row0_col4" class="data row0 col4" >1569910.210468</td>
#       <td id="T_c7b54_row0_col5" class="data row0 col5" >7457073.499721</td>
#       <td id="T_c7b54_row0_col6" class="data row0 col6" >4 days 18:00:00</td>
#       <td id="T_c7b54_row0_col7" class="data row0 col7" >2022-03-13 15:00:00</td>
#       <td id="T_c7b54_row0_col8" class="data row0 col8" >2022-03-18 06:00:00</td>
#       <td id="T_c7b54_row0_col9" class="data row0 col9" >-85.000000</td>
#       <td id="T_c7b54_row0_col10" class="data row0 col10" >278.642639</td>
#       <td id="T_c7b54_row0_col11" class="data row0 col11" >0.531637</td>
#       <td id="T_c7b54_row0_col12" class="data row0 col12" >15.266479</td>
#       <td id="T_c7b54_row0_col13" class="data row0 col13" >8.315104</td>
#       <td id="T_c7b54_row0_col14" class="data row0 col14" >21.859558</td>
#       <td id="T_c7b54_row0_col15" class="data row0 col15" >4.008752</td>
#       <td id="T_c7b54_row0_col16" class="data row0 col16" >23.074251</td>
#       <td id="T_c7b54_row0_col17" class="data row0 col17" >16.122986</td>
#       <td id="T_c7b54_row0_col18" class="data row0 col18" >45.662140</td>
#       <td id="T_c7b54_row0_col19" class="data row0 col19" >96281.687500</td>
#       <td id="T_c7b54_row0_col20" class="data row0 col20" >40.972366</td>
#       <td id="T_c7b54_row0_col21" class="data row0 col21" >63.922712</td>
#       <td id="T_c7b54_row0_col22" class="data row0 col22" >482.539856</td>
#       <td id="T_c7b54_row0_col23" class="data row0 col23" >351.682389</td>
#       <td id="T_c7b54_row0_col24" class="data row0 col24" >1251.982056</td>
#       <td id="T_c7b54_row0_col25" class="data row0 col25" >679245650359.845337</td>
#       <td id="T_c7b54_row0_col26" class="data row0 col26" >72319870204593.062500</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=catalog, x='cumulative_snowfall_ais', bins=20);
plt.title('Cumulative Snowfall on AIS');
plt.xlabel('Cumulative Snowfall (kg)');

# %% [markdown]
# **Fun Fact**: the storm that dumped the most snowfall on record of any AR in the catalog was the one that caused the 2022 heat wave.

# %%
display_catalog(catalog.loc[[catalog.cumulative_snowfall_ais.idxmax()]])
# Out:
# <style type="text/css">
# </style>
# <table id="T_0b58c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b58c_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_0b58c_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_0b58c_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_0b58c_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_0b58c_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_0b58c_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_0b58c_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_0b58c_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_0b58c_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_0b58c_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_0b58c_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_0b58c_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_0b58c_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_0b58c_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_0b58c_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_0b58c_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_0b58c_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_0b58c_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_0b58c_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_0b58c_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_0b58c_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_0b58c_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_0b58c_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_0b58c_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_0b58c_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_0b58c_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_0b58c_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b58c_level0_row0" class="row_heading level0 row0" >8137</th>
#       <td id="T_0b58c_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_0b58c_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_0b58c_row0_col2" class="data row0 col2" >6299194.344214</td>
#       <td id="T_0b58c_row0_col3" class="data row0 col3" >3403828.602753</td>
#       <td id="T_0b58c_row0_col4" class="data row0 col4" >1569910.210468</td>
#       <td id="T_0b58c_row0_col5" class="data row0 col5" >7457073.499721</td>
#       <td id="T_0b58c_row0_col6" class="data row0 col6" >4 days 18:00:00</td>
#       <td id="T_0b58c_row0_col7" class="data row0 col7" >2022-03-13 15:00:00</td>
#       <td id="T_0b58c_row0_col8" class="data row0 col8" >2022-03-18 06:00:00</td>
#       <td id="T_0b58c_row0_col9" class="data row0 col9" >-85.000000</td>
#       <td id="T_0b58c_row0_col10" class="data row0 col10" >278.642639</td>
#       <td id="T_0b58c_row0_col11" class="data row0 col11" >0.531637</td>
#       <td id="T_0b58c_row0_col12" class="data row0 col12" >15.266479</td>
#       <td id="T_0b58c_row0_col13" class="data row0 col13" >8.315104</td>
#       <td id="T_0b58c_row0_col14" class="data row0 col14" >21.859558</td>
#       <td id="T_0b58c_row0_col15" class="data row0 col15" >4.008752</td>
#       <td id="T_0b58c_row0_col16" class="data row0 col16" >23.074251</td>
#       <td id="T_0b58c_row0_col17" class="data row0 col17" >16.122986</td>
#       <td id="T_0b58c_row0_col18" class="data row0 col18" >45.662140</td>
#       <td id="T_0b58c_row0_col19" class="data row0 col19" >96281.687500</td>
#       <td id="T_0b58c_row0_col20" class="data row0 col20" >40.972366</td>
#       <td id="T_0b58c_row0_col21" class="data row0 col21" >63.922712</td>
#       <td id="T_0b58c_row0_col22" class="data row0 col22" >482.539856</td>
#       <td id="T_0b58c_row0_col23" class="data row0 col23" >351.682389</td>
#       <td id="T_0b58c_row0_col24" class="data row0 col24" >1251.982056</td>
#       <td id="T_0b58c_row0_col25" class="data row0 col25" >679245650359.845337</td>
#       <td id="T_0b58c_row0_col26" class="data row0 col26" >72319870204593.062500</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=catalog.loc[catalog.cumulative_rainfall_ais > 0], x='cumulative_rainfall_ais', bins=50);
plt.title('Cumulative Rainfall Dumped on AIS');
plt.xlabel('Cumulative Rainfall (kg)');

# %% [markdown]
# **Fun Fact**: storm that dumped the most rain on record (almost twice the amount of rain as the next biggest storm) is an AR from February 2022, studied in Gorodestskaya et al. (2023) (*Record-high Antarctic Peninsula temperatures and surface melt in February 2022: a compound event with an intense atmospheric river*)

# %%
display_catalog(catalog.loc[[catalog.cumulative_rainfall_ais.idxmax()]])
# Out:
# <style type="text/css">
# </style>
# <table id="T_6d950">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d950_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_6d950_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_6d950_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_6d950_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_6d950_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_6d950_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_6d950_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_6d950_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_6d950_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_6d950_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_6d950_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_6d950_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_6d950_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_6d950_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_6d950_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_6d950_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_6d950_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_6d950_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_6d950_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_6d950_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_6d950_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_6d950_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_6d950_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_6d950_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_6d950_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_6d950_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_6d950_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d950_level0_row0" class="row_heading level0 row0" >8117</th>
#       <td id="T_6d950_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_6d950_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_6d950_row0_col2" class="data row0 col2" >3877096.641947</td>
#       <td id="T_6d950_row0_col3" class="data row0 col3" >2475621.043861</td>
#       <td id="T_6d950_row0_col4" class="data row0 col4" >714979.068131</td>
#       <td id="T_6d950_row0_col5" class="data row0 col5" >3038661.039558</td>
#       <td id="T_6d950_row0_col6" class="data row0 col6" >4 days 06:00:00</td>
#       <td id="T_6d950_row0_col7" class="data row0 col7" >2022-02-05 03:00:00</td>
#       <td id="T_6d950_row0_col8" class="data row0 col8" >2022-02-09 06:00:00</td>
#       <td id="T_6d950_row0_col9" class="data row0 col9" >-85.000000</td>
#       <td id="T_6d950_row0_col10" class="data row0 col10" >279.027313</td>
#       <td id="T_6d950_row0_col11" class="data row0 col11" >2.962659</td>
#       <td id="T_6d950_row0_col12" class="data row0 col12" >17.935772</td>
#       <td id="T_6d950_row0_col13" class="data row0 col13" >8.916690</td>
#       <td id="T_6d950_row0_col14" class="data row0 col14" >20.950256</td>
#       <td id="T_6d950_row0_col15" class="data row0 col15" >10.689799</td>
#       <td id="T_6d950_row0_col16" class="data row0 col16" >27.609982</td>
#       <td id="T_6d950_row0_col17" class="data row0 col17" >20.262910</td>
#       <td id="T_6d950_row0_col18" class="data row0 col18" >45.593719</td>
#       <td id="T_6d950_row0_col19" class="data row0 col19" >97738.375000</td>
#       <td id="T_6d950_row0_col20" class="data row0 col20" >20.089249</td>
#       <td id="T_6d950_row0_col21" class="data row0 col21" >155.249612</td>
#       <td id="T_6d950_row0_col22" class="data row0 col22" >748.183411</td>
#       <td id="T_6d950_row0_col23" class="data row0 col23" >392.403089</td>
#       <td id="T_6d950_row0_col24" class="data row0 col24" >1125.843506</td>
#       <td id="T_6d950_row0_col25" class="data row0 col25" >3888114518459.414551</td>
#       <td id="T_6d950_row0_col26" class="data row0 col26" >37807737218603.226562</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Among all ARs, every AR dumped some snow. Among those ARs, about 38% of them also dumped rain.

# %%
data_crosstab = pd.crosstab(catalog.cumulative_rainfall_ais > 0, 
                            catalog.cumulative_snowfall_ais > 0,  
                               margins = False, normalize='all') 
data_crosstab
# Out:
# cumulative_snowfall_ais      True
# cumulative_rainfall_ais
# False                    0.618746
# True                     0.381254

# %%
display_catalog(catalog.loc[[catalog.cumulative_rainfall_ais.idxmax()]])
# Out:
# <style type="text/css">
# </style>
# <table id="T_ffed0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffed0_level0_col0" class="col_heading level0 col0" >data_array</th>
#       <th id="T_ffed0_level0_col1" class="col_heading level0 col1" >is_landfalling</th>
#       <th id="T_ffed0_level0_col2" class="col_heading level0 col2" >max_area</th>
#       <th id="T_ffed0_level0_col3" class="col_heading level0 col3" >mean_area</th>
#       <th id="T_ffed0_level0_col4" class="col_heading level0 col4" >mean_landfalling_area</th>
#       <th id="T_ffed0_level0_col5" class="col_heading level0 col5" >cumulative_landfalling_area</th>
#       <th id="T_ffed0_level0_col6" class="col_heading level0 col6" >duration</th>
#       <th id="T_ffed0_level0_col7" class="col_heading level0 col7" >start_date</th>
#       <th id="T_ffed0_level0_col8" class="col_heading level0 col8" >end_date</th>
#       <th id="T_ffed0_level0_col9" class="col_heading level0 col9" >max_south_extent</th>
#       <th id="T_ffed0_level0_col10" class="col_heading level0 col10" >max_T2m_ais</th>
#       <th id="T_ffed0_level0_col11" class="col_heading level0 col11" >avg_V10m_ais</th>
#       <th id="T_ffed0_level0_col12" class="col_heading level0 col12" >max_V10m_ais</th>
#       <th id="T_ffed0_level0_col13" class="col_heading level0 col13" >avg_V10m</th>
#       <th id="T_ffed0_level0_col14" class="col_heading level0 col14" >max_V10m</th>
#       <th id="T_ffed0_level0_col15" class="col_heading level0 col15" >avg_IWV_ais</th>
#       <th id="T_ffed0_level0_col16" class="col_heading level0 col16" >max_IWV_ais</th>
#       <th id="T_ffed0_level0_col17" class="col_heading level0 col17" >avg_IWV</th>
#       <th id="T_ffed0_level0_col18" class="col_heading level0 col18" >max_IWV</th>
#       <th id="T_ffed0_level0_col19" class="col_heading level0 col19" >landfalling_SLP</th>
#       <th id="T_ffed0_level0_col20" class="col_heading level0 col20" >max_T2M_anomaly_ais</th>
#       <th id="T_ffed0_level0_col21" class="col_heading level0 col21" >avg_vIVT_ais</th>
#       <th id="T_ffed0_level0_col22" class="col_heading level0 col22" >max_vIVT_ais</th>
#       <th id="T_ffed0_level0_col23" class="col_heading level0 col23" >avg_vIVT</th>
#       <th id="T_ffed0_level0_col24" class="col_heading level0 col24" >max_vIVT</th>
#       <th id="T_ffed0_level0_col25" class="col_heading level0 col25" >cumulative_rainfall_ais</th>
#       <th id="T_ffed0_level0_col26" class="col_heading level0 col26" >cumulative_snowfall_ais</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffed0_level0_row0" class="row_heading level0 row0" >8117</th>
#       <td id="T_ffed0_row0_col0" class="data row0 col0" ><img src="data:image/png;base64,..." /></td>
#       <td id="T_ffed0_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_ffed0_row0_col2" class="data row0 col2" >3877096.641947</td>
#       <td id="T_ffed0_row0_col3" class="data row0 col3" >2475621.043861</td>
#       <td id="T_ffed0_row0_col4" class="data row0 col4" >714979.068131</td>
#       <td id="T_ffed0_row0_col5" class="data row0 col5" >3038661.039558</td>
#       <td id="T_ffed0_row0_col6" class="data row0 col6" >4 days 06:00:00</td>
#       <td id="T_ffed0_row0_col7" class="data row0 col7" >2022-02-05 03:00:00</td>
#       <td id="T_ffed0_row0_col8" class="data row0 col8" >2022-02-09 06:00:00</td>
#       <td id="T_ffed0_row0_col9" class="data row0 col9" >-85.000000</td>
#       <td id="T_ffed0_row0_col10" class="data row0 col10" >279.027313</td>
#       <td id="T_ffed0_row0_col11" class="data row0 col11" >2.962659</td>
#       <td id="T_ffed0_row0_col12" class="data row0 col12" >17.935772</td>
#       <td id="T_ffed0_row0_col13" class="data row0 col13" >8.916690</td>
#       <td id="T_ffed0_row0_col14" class="data row0 col14" >20.950256</td>
#       <td id="T_ffed0_row0_col15" class="data row0 col15" >10.689799</td>
#       <td id="T_ffed0_row0_col16" class="data row0 col16" >27.609982</td>
#       <td id="T_ffed0_row0_col17" class="data row0 col17" >20.262910</td>
#       <td id="T_ffed0_row0_col18" class="data row0 col18" >45.593719</td>
#       <td id="T_ffed0_row0_col19" class="data row0 col19" >97738.375000</td>
#       <td id="T_ffed0_row0_col20" class="data row0 col20" >20.089249</td>
#       <td id="T_ffed0_row0_col21" class="data row0 col21" >155.249612</td>
#       <td id="T_ffed0_row0_col22" class="data row0 col22" >748.183411</td>
#       <td id="T_ffed0_row0_col23" class="data row0 col23" >392.403089</td>
#       <td id="T_ffed0_row0_col24" class="data row0 col24" >1125.843506</td>
#       <td id="T_ffed0_row0_col25" class="data row0 col25" >3888114518459.414551</td>
#       <td id="T_ffed0_row0_col26" class="data row0 col26" >37807737218603.226562</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Multi-variable Plots

# %%
sns.scatterplot(data=catalog, x='max_T2M_anomaly_ais', y='cumulative_snowfall_ais', alpha=0.05)
# Out:
# <Axes: xlabel='max_T2M_anomaly_ais', ylabel='cumulative_snowfall_ais'>

# %%
sns.scatterplot(data=catalog, x='max_T2m_ais', y='cumulative_rainfall_ais', alpha=0.05)
# Out:
# <Axes: xlabel='max_T2m_ais', ylabel='cumulative_rainfall_ais'>

# %%
sns.scatterplot(data=catalog, x='avg_IWV_ais', y='max_T2M_anomaly_ais', alpha=0.05)
# Out:
# <Axes: xlabel='avg_IWV_ais', ylabel='max_T2M_anomaly_ais'>

# %%
sns.scatterplot(data=catalog, x='avg_V10m', y='max_T2M_anomaly_ais', alpha=0.1)
# Out:
# <Axes: xlabel='avg_V10m', ylabel='max_T2M_anomaly_ais'>

# %%
sns.scatterplot(data=catalog, x='mean_landfalling_area', y='max_T2M_anomaly_ais', alpha=0.1)
# Out:
# <Axes: xlabel='mean_landfalling_area', ylabel='max_T2M_anomaly_ais'>

# %%
sns.scatterplot(data=catalog, x='cumulative_landfalling_area', y='max_T2M_anomaly_ais', alpha=0.1)
# Out:
# <Axes: xlabel='cumulative_landfalling_area', ylabel='max_T2M_anomaly_ais'>

# %%
sns.scatterplot(data=catalog, x='cumulative_landfalling_area', y='cumulative_snowfall_ais', alpha=0.05)
# Out:
# <Axes: xlabel='cumulative_landfalling_area', ylabel='cumulative_snowfall_ais'>

# %%
sns.scatterplot(data=catalog, x='duration', y='cumulative_snowfall_ais', alpha=0.05)
# Out:
# <Axes: xlabel='duration', ylabel='cumulative_snowfall_ais'>

# %%
sns.scatterplot(data=catalog[catalog.landfalling_SLP < 1000000], x='landfalling_SLP', y='cumulative_snowfall_ais', alpha=0.05)
# Out:
# <Axes: xlabel='landfalling_SLP', ylabel='cumulative_snowfall_ais'>

# %%
sns.scatterplot(data=catalog[catalog.landfalling_SLP < 1000000], x='landfalling_SLP', y='cumulative_rainfall_ais', alpha=0.05)
# Out:
# <Axes: xlabel='landfalling_SLP', ylabel='cumulative_rainfall_ais'>

# %%
sns.scatterplot(data=catalog, x='avg_V10m', y='cumulative_snowfall_ais', alpha=0.05)
# Out:
# <Axes: xlabel='avg_V10m', ylabel='cumulative_snowfall_ais'>

# %%
sns.scatterplot(data=high_impact, x='avg_V10m', y='cumulative_snowfall_ais', alpha=0.1)
# Out:
# <Axes: xlabel='avg_V10m', ylabel='cumulative_snowfall_ais'>

# %%
vals_ais = catalog[['max_T2M_anomaly_ais', 'cumulative_snowfall_ais', 'cumulative_rainfall_ais', 'max_T2m_ais', 'cumulative_landfalling_area', 'mean_landfalling_area', 'duration', 'landfalling_SLP', 'max_V10m_ais', 'max_IWV_ais', 'max_vIVT_ais', 'max_south_extent']]

# %%
vals_ais.corr()[['max_T2M_anomaly_ais', 'cumulative_snowfall_ais', 'cumulative_rainfall_ais', 'max_T2m_ais']]
# Out:
#                              max_T2M_anomaly_ais  cumulative_snowfall_ais  \
# max_T2M_anomaly_ais                     1.000000                 0.552653
# cumulative_snowfall_ais                 0.552653                 1.000000
# cumulative_rainfall_ais                 0.017878                 0.250135
# max_T2m_ais                             0.215000                 0.405331
# cumulative_landfalling_area             0.501266                 0.877742
# mean_landfalling_area                   0.538818                 0.613771
# duration                                0.286098                 0.567072
# landfalling_SLP                        -0.042744                -0.118309
# max_V10m_ais                            0.605238                 0.527221
# max_IWV_ais                             0.079915                 0.457502
# max_vIVT_ais                            0.336097                 0.623039
# max_south_extent                       -0.652973                -0.543748
#
#                              cumulative_rainfall_ais  max_T2m_ais
# max_T2M_anomaly_ais                         0.017878     0.215000
# cumulative_snowfall_ais                     0.250135     0.405331
# cumulative_rainfall_ais                     1.000000     0.240322
# max_T2m_ais                                 0.240322     1.000000
# cumulative_landfalling_area                 0.166068     0.303307
# mean_landfalling_area                       0.075049     0.248723
# duration                                    0.157352     0.275517
# landfalling_SLP                            -0.028675    -0.291694
# max_V10m_ais                                0.134944     0.450935
# max_IWV_ais                                 0.418933     0.775768
# max_vIVT_ais                                0.412417     0.663872
# max_south_extent                           -0.100724    -0.249705

# %% [markdown]
# Findings:
#
# + Modestly positive associations between the AIS 2m-Temp Anomaly and spatial extent of storm (to a lesser extent, duration), the max 10m poleward wind speed. Modest positive association with vIVT, but this seems to be due to associations with V rather than IWV, which has a seemingly negligible correlation. Strong negative association between max southward extent and 2m temperature anomaly (AKA, storms that penetrate further south have higher temp anomalies). No real association between the landfalling SLP and the temperature anomalies.
#
# + Strong positive association between snowfall and notions of duration and extent over the ice sheet. Somewhat negative association between landfalling SLP and snowfall? At least higher than 2m temp anomalies. Modest positive associations between 10m windspeed and IWV, producing a modest association with vIVT. Also association between how far it penetrates downward into continent and the cumulative snowfall.
#
# + Less strong associations between absolute 2m-temp and notions of duration and extent over ice sheet. More negative association with SLP. MUCH stronger association with IWV than the anomaly had: is this picking up on storms making landfall near the coast/the AP storms? Much less association of how far the storm penetrates southward on the continent with absolute temp.

# %%
catalog['cumulative_snowfall_ais'] = catalog['cumulative_snowfall_ais']/10**13
catalog['landfalling_SLP'] = catalog['landfalling_SLP']/10**2

# %%
fig, axs = plt.subplots(nrows=2, ncols=5)
fig.set_size_inches(18, 6)

corr = round(pearsonr(catalog.max_V10m_ais, catalog.max_T2M_anomaly_ais).statistic, 2)
sns.kdeplot(data=catalog, x="max_V10m_ais", y="max_T2M_anomaly_ais", fill=True, ax=axs[0,0])
axs[0,0].set_xlabel('Max 10m-Poleward Wind (m/s)')
axs[0,0].set_ylabel('Max 2m-Temp Anomaly ($\\circ C$)')
axs[0,0].annotate(text='$\\rho$ = '+ str(corr), xy=(0.50, 0.85), xycoords='axes fraction', fontsize=18);

corr = round(pearsonr(catalog.max_IWV_ais, catalog.max_T2M_anomaly_ais).statistic, 2)
sns.kdeplot(data=catalog, x="max_IWV_ais", y="max_T2M_anomaly_ais", fill=True, ax=axs[0,1])
axs[0,1].set_xlabel('Max IWV (kg/m$^{2}$)')
axs[0,1].set_ylabel('')
axs[0,1].annotate(text='$\\rho$ = '+ str(corr), xy=(0.5, 0.85), xycoords='axes fraction', fontsize=18);

corr = round(pearsonr(catalog.cumulative_landfalling_area, catalog.max_T2M_anomaly_ais).statistic, 2)
sns.kdeplot(data=catalog, x="cumulative_landfalling_area", y="max_T2M_anomaly_ais", fill=True, ax=axs[0,2])
axs[0,2].set_xlabel('CLA (km$^{2} $ day)')
axs[0,2].set_ylabel('')
axs[0,2].set_xlim(-0.5*(10**6), 3*(10**6))
axs[0,2].annotate(text='$\\rho$ = '+ str(corr), xy=(0.5, 0.85), xycoords='axes fraction', fontsize=18);

corr = round(pearsonr(catalog.max_south_extent, catalog.max_T2M_anomaly_ais).statistic, 2)
sns.kdeplot(data=catalog, x="max_south_extent", y="max_T2M_anomaly_ais", fill=True, ax=axs[0,3])
axs[0,3].set_xlabel('Max South Extent (degrees)')
axs[0,3].set_ylabel('')
#axs[3].set_xlim(, 4*(10**6))
axs[0,3].annotate(text='$\\rho$ = '+ str(corr), xy=(0.5, 0.85), xycoords='axes fraction', fontsize=18);

corr = round(pearsonr(catalog.landfalling_SLP, catalog.max_T2M_anomaly_ais).statistic, 2)
sns.kdeplot(data=catalog, x="landfalling_SLP", y="max_T2M_anomaly_ais", fill=True, ax=axs[0,4])
axs[0,4].set_xlabel('Min SLP at Landfall (Pa)')
axs[0,4].set_ylabel('')
#axs[3].set_xlim(, 4*(10**6))
axs[0,4].annotate(text='$\\rho$ = '+ str(corr), xy=(0.5, 0.85), xycoords='axes fraction', fontsize=18);

corr = round(pearsonr(catalog.max_V10m_ais, catalog.cumulative_snowfall_ais).statistic, 2)
sns.kdeplot(data=catalog, x="max_V10m_ais", y="cumulative_snowfall_ais", fill=True, ax=axs[1,0])
axs[1,0].set_xlabel('Max 10m-Poleward Wind (m/s)')
axs[1,0].set_ylabel('Cumulative AIS Snowfall (gigatonnes)')
axs[1,0].set_ylim(-0.2, 3)
axs[1,0].annotate(text='$\\rho$ = '+ str(corr), xy=(0.50, 0.85), xycoords='axes fraction', fontsize=18);

corr = round(pearsonr(catalog.max_IWV_ais, catalog.cumulative_snowfall_ais).statistic, 2)
sns.kdeplot(data=catalog, x="max_IWV_ais", y="cumulative_snowfall_ais", fill=True, ax=axs[1,1])
axs[1,1].set_xlabel('Max IWV (kg/m$^{2}$)')
axs[1,1].set_ylabel('')
axs[1,1].set_ylim(-0.2, 3)
axs[1,1].annotate(text='$\\rho$ = '+ str(corr), xy=(0.50, 0.85), xycoords='axes fraction', fontsize=18);

corr = round(pearsonr(catalog.cumulative_landfalling_area, catalog.cumulative_snowfall_ais).statistic, 2)
sns.kdeplot(data=catalog, x="cumulative_landfalling_area", y="cumulative_snowfall_ais", fill=True, ax=axs[1,2])
axs[1,2].set_xlabel('CLA (km$^{2} $ day)')
axs[1,2].set_xlim(-0.5*(10**6), 3*(10**6))
axs[1,2].set_ylabel('')
axs[1,2].set_ylim(-0.2, 3)
axs[1,2].annotate(text='$\\rho$ = '+ str(corr), xy=(0.50, 0.85), xycoords='axes fraction', fontsize=18);

corr = round(pearsonr(catalog.max_south_extent, catalog.cumulative_snowfall_ais).statistic, 2)
sns.kdeplot(data=catalog, x="max_south_extent", y="cumulative_snowfall_ais", fill=True, ax=axs[1,3])
axs[1,3].set_xlabel('Max South Extent (degrees)')
axs[1,3].set_ylabel('')
axs[1,3].set_ylim(-0.2, 3)
axs[1,3].annotate(text='$\\rho$ = '+ str(corr), xy=(0.5, 0.85), xycoords='axes fraction', fontsize=18);

corr = round(pearsonr(catalog.landfalling_SLP, catalog.cumulative_snowfall_ais).statistic, 2)
sns.kdeplot(data=catalog, x="landfalling_SLP", y="cumulative_snowfall_ais", fill=True, ax=axs[1,4])
axs[1,4].set_xlabel('Min SLP at Landfall (Pa)')
axs[1,4].set_ylabel('')
axs[1,4].set_ylim(-0.2, 3)
axs[1,4].annotate(text='$\\rho$ = '+ str(corr), xy=(0.5, 0.85), xycoords='axes fraction', fontsize=18);

# %%
sns.kdeplot(data=catalog, x="cumulative_landfalling_area", y="max_T2M_anomaly_ais")
# Out:
# <Axes: xlabel='cumulative_landfalling_area', ylabel='max_T2M_anomaly_ais'>

# %%
sns.kdeplot(data=catalog, x="landfalling_SLP", y="max_T2M_anomaly_ais")
# Out:
# <Axes: xlabel='landfalling_SLP', ylabel='max_T2M_anomaly_ais'>

# %%
sns.kdeplot(data=catalog, x="max_IWV_ais", y="max_T2M_anomaly_ais")
# Out:
# <Axes: xlabel='max_IWV_ais', ylabel='max_T2M_anomaly_ais'>

# %%
sns.kdeplot(data=catalog, x="max_south_extent", y="max_T2M_anomaly_ais")
# Out:
# <Axes: xlabel='max_south_extent', ylabel='max_T2M_anomaly_ais'>

# %%
sns.kdeplot(data=catalog, x="max_V10m_ais", y="cumulative_snowfall_ais")
# Out:
# <Axes: xlabel='max_V10m_ais', ylabel='cumulative_snowfall_ais'>

# %%
sns.kdeplot(data=catalog, x="max_IWV_ais", y="cumulative_snowfall_ais")
# Out:
# <Axes: xlabel='max_IWV_ais', ylabel='cumulative_snowfall_ais'>

# %%
sns.kdeplot(data=catalog, x="cumulative_landfalling_area", y="cumulative_snowfall_ais")
# Out:
# <Axes: xlabel='cumulative_landfalling_area', ylabel='cumulative_snowfall_ais'>

# %%
sns.kdeplot(data=catalog, x="max_south_extent", y="cumulative_snowfall_ais")
# Out:
# <Axes: xlabel='max_south_extent', ylabel='cumulative_snowfall_ais'>

# %% [markdown]
# ### Other Analyses

# %% [markdown]
# ### PCA
