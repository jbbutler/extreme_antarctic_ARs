# %% [markdown]
# # JSON Construction
#
# Helper notebook to construct json representations of python dictionaries, with all of the hyperparameters to test via CV in a certain round of hyperparam searching.
#
# Jimmy Butler,
# 10/5/2025

# %%
import numpy as np
import json
import os
curwd = os.getcwd()

# %%
hyperparam_dict = {}

hyperparam_dict['etas'] = [0.3, 0.1, 0.05, 0.01, 0.001]
hyperparam_dict['gammas'] = np.array([0, 0.0001, 0.001, 0.01, 1, 10, 100]).tolist()
hyperparam_dict['max_depth'] = np.array([1, 3, 5, 7, 10, 15]).tolist()
hyperparam_dict['lambdas'] = np.array([0, 0.001, 0.01, 0.1, 10, 100]).tolist()
hyperparam_dict['min_child_weights'] = np.array([0, 10, 50, 100, 500, 1000]).tolist()
hyperparam_dict['nrounds'] = 20000
hyperparam_dict['early_stopping_rounds'] = 20
hyperparam_dict['tree_method'] = 'exact'
hyperparam_dict['booster'] = 'gbtree'

# %%
hyperparam_dict = {}
hyperparam_dict['etas'] = [0.3, 0.1, 0.2]
hyperparam_dict['gammas'] = np.array([0, 5, 10]).tolist()
hyperparam_dict['max_depth'] = np.array([1]).tolist()
hyperparam_dict['lambdas'] = np.array([0]).tolist()
hyperparam_dict['min_child_weights'] = np.array([0]).tolist()
hyperparam_dict['nrounds'] = 20000
hyperparam_dict['early_stopping_rounds'] = 20
hyperparam_dict['tree_method'] = 'exact'
hyperparam_dict['booster'] = 'gbtree'

# %%
with open(curwd + '/rounds/temp_round1_hyperparams.json', 'w') as json_file:
    json.dump(hyperparam_dict, json_file, indent=4)
