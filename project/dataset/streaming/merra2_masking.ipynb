# %% [markdown]
# # MERRA-2 Masking
#
# Filling in the dataset of ARs by masking quantities from MERRA-2, streaming the data directly in. Uses findings and explorations from `streaming_demos.ipynb` as a basis for implementation.
#
# Jimmy Butler, November 2025
