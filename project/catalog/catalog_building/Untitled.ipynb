# %%
import reanalysis_masking

# %%
help(reanalysis_masking)
# Out:
# Help on module reanalysis_masking:
#
# NAME
#     reanalysis_masking
#
# DESCRIPTION
#     Script that will fill in the dataframe of AR events with relevant information
#     about each storm, like durations, landfalling regions as well as masking re-analysis
#     data to obtain quantities like snowfall, moisture content, energy, etc.
#
#     Jimmy Butler
#     June 2025
#
# FILE
#     /accounts/grad/butlerj/extreme_antarctic_ARs/project/catalog/catalog_building/reanalysis_masking.py
