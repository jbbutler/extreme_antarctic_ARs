# %%
import reanalysis_masking

# %%
help(reanalysis_masking)
# Out:
# Help on module reanalysis_masking:
#
# NAME
#     reanalysis_masking
#
# DESCRIPTION
#     Script that will fill in the dataframe of AR events with relevant information
#     about each storm, like durations, landfalling regions as well as masking re-analysis
#     data to obtain quantities like snowfall, moisture content, energy, etc.
#
#     Jimmy Butler
#     June 2025
#
# FILE
#     /accounts/grad/butlerj/extreme_antarctic_ARs/project/catalog/catalog_building/reanalysis_masking.py

# %%
import os

# %%
os.getcwd()
# Out:
# '/accounts/grad/butlerj/extreme_antarctic_ARs/project/catalog/catalog_building'

# %%
import pandas as pd
df = pd.read_hdf('~/extreme_antarctic_ARs/project/catalog/epsspace0.5_epstime12_minpts5_nreppts10_seed12345.h5')

# %%
das = df.iloc[0:10].data_array

# %%
import sys
sys.path.append(str(Path(os.getcwd()).parents[2]/'packages'))

# %%
import os
from pathlib import Path

# %%
from loading_utils import load_ais
from loading_utils import load_catalogs

# %%
cats = load_catalogs([1980])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/antarctic_ars/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/.conda/envs/antarctic_ars/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/accounts/grad/butlerj/extreme_antarctic_ARs/project/input_data/wille_ar_catalogs/*.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'f4d25e00-2a50-41f5-82f5-afc3de297ca1']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
i = 1
df.iloc[1].is_landfalling
# Out:
# np.False_

# %%
da = df.iloc[1].data_array

# %%
(ais*da).any().values
# Out:
# array(False)

# %%
from attribute_utils import is_landfalling

# %%
is_landfalling(da)
# Out:
# array(False)

# %%
das.apply(is_landfalling)
# Out:
# cluster
# 1.0      True
# 2.0     False
# 3.0      True
# 4.0     False
# 5.0      True
# 6.0      True
# 7.0     False
# 8.0     False
# 9.0     False
# 10.0    False
# Name: data_array, dtype: bool

# %%
df.iloc[0:10].is_landfalling
# Out:
# cluster
# 1.0      True
# 2.0     False
# 3.0      True
# 4.0     False
# 5.0      True
# 6.0      True
# 7.0     False
# 8.0     False
# 9.0     False
# 10.0    False
# Name: is_landfalling, dtype: bool

# %%
import pandas as pd

import sys
sys.path.append(str(Path(__file__).parents[3]/'packages'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       1 import pandas as pd
#       3 import sys
# ----> 4 sys.path.append(str(Path(__file__).parents[3]/'packages'))
#
# NameError: name '__file__' is not defined

# %%
res = pd.read_hdf('epsspace0.5_epstime12_minpts5_nreppts10_seed12345.h5')

# %%
# Out:
# np.True_

# %%
a = res.iloc[0:190].apply(lambda x: is_landfalling(x))

# %%
a
# Out:
# cluster
# 1.0       True
# 3.0      False
# 4.0       True
# 5.0       True
# 6.0       True
#          ...
# 194.0    False
# 195.0    False
# 196.0     True
# 197.0    False
# 198.0    False
# Name: data_array, Length: 190, dtype: bool

# %%
is_landfalling(res.iloc[190])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 is_landfalling(res.iloc[190])
#
# File ~/extreme_antarctic_ARs/packages/attribute_utils.py:23, in is_landfalling(ar_da)
#      12 def is_landfalling(ar_da):
#      13     '''
#      14     Function to determine if a given AR has made landfall on the AIS.
#      15
#    (...)
#      20         is_landfalling (boolean): whether the AR intersected the AIS at any point in time
#      21     '''
# ---> 23     is_landfalling = (ais_mask*ar_da).any().values
#      25     return is_landfalling
#
# File ~/.conda/envs/antarctic_ars/lib/python3.12/site-packages/xarray/core/_typed_ops.py:252, in DataArrayOpsMixin.__mul__(self, other)
#     251 def __mul__(self, other: DaCompatible) -> Self:
# --> 252     return self._binary_op(other, operator.mul)
#
# ...
